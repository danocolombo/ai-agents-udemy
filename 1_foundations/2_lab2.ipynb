# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# How would you, as an independent expert advising the government of a mid-sized coastal city (population ~350,000) with 10 years to prepare for a projected 1.0–1.5 m sea-level rise, aging infrastructure, an economy heavily dependent on tourism, a projected 15% population increase from climate migration, and constrained fiscal capacity (total available investment over the next decade equal to 40% of one year's current municipal budget), develop a prioritized, time‑phased 10‑year action plan that includes: (a) budget allocation percentages across categories [infrastructure, housing, social services, economic diversification, environmental restoration, governance/participation, emergency response]; (b) for each major action, the expected benefits, risks, and failure modes; (c) three high‑leverage early investments that maximize optionality; (d) the critical data needed, how to collect it, and a monitoring/decision‑rule framework for adaptive management; (e) the main ethical trade‑offs, distributional impacts, and compensation strategies for vulnerable groups; (f) the top five assumptions and their sensitivity; (g) probabilistic forecasts (with uncertainty ranges) for best‑case, likely‑case, and worst‑case outcomes after 10 years; and (h) your confidence (0–100%) in the plan with justification — providing first a concise summary of up to four sentences and then a detailed plan of up to 1000 words?

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Concise executive summary (4 sentences)
# Plan a 10-year, climate-resilient upgrade with total investments equal to 40% of one annual city budget, prioritizing scalable protection, housing resilience, economic diversification, and nature-based solutions. It centers a data-driven, adaptive governance approach, supported by a small set of high-leverage early investments that preserve optionality for uncertain futures. Three early bets anchor flexibility: (i) a city-scale coastal risk data hub and decision framework, (ii) a flexible relocation/housing fund with enabling land-use tools, and (iii) scalable nature-based coastal defenses tied to ecological restoration. Probabilistic forecasts indicate a reasonable chance of substantial resilience gains but wide uncertainty around tourism revenue, housing stress, and flood exposure, underscoring the need for continuous monitoring and adaptive management.
#
# Detailed plan (up to ~1000 words)
#
# (a) Budget allocation percentages across categories (over the 10-year investment total equal to 0.4 of one year’s current municipal budget)
# - Infrastructure (gray/physical resilience): 28%
# - Housing (affordable, resilient, relocation readiness): 22%
# - Social services (health, education, social protection for vulnerable groups): 14%
# - Economic diversification (tourism resilience, local business support, diversification of revenue): 14%
# - Environmental restoration and nature-based solutions (coastal wetlands, mangroves, dunes, green-blue corridors): 12%
# - Governance/participation (civic engagement, transparency, data platforms, governance reforms): 4%
# - Emergency response (early warning, evacuation planning, mutual aid, capacity building): 6%
# Notes: These percentages reflect a balanced emphasis on hardening critical assets, protecting vulnerable residents, and expanding the city’s capacity to adapt to evolving risks, while staying within the 0.4x annual budget constraint.
#
# (b) For each major action, expected benefits, risks, and failure modes
# 1) Coastal resilience infrastructure upgrade (modular, scalable seawalls, flood barriers, pump stations, elevated transport corridors)
# - Benefits: reduces inundation risk for critical facilities; preserves tourism accessibility; creates clear, codified adaptation pathways.
# - Risks: high upfront cost, potential ecological disruption, maintenance burden; failure modes include design underestimation of flood magnitudes and insufficient operation plans.
# - Failure modes: insufficient coordination with natural systems, cost overruns, delayed procurement, misalignment with future land use.
#
# 2) Housing resilience and relocation planning (affordable, climate-ready housing; voluntary buyouts and relocation pilots; policy incentives)
# - Benefits: protects vulnerable households, reduces disaster exposure, supports demographic resilience.
# - Risks: affordability gaps, displacement if incentives are insufficient, social friction.
# - Failure modes: delayed buyouts, uneven access to subsidies, legal challenges to land acquisition.
#
# 3) Economic diversification and tourism resilience (local supply chains, climate-smart tourism offerings, small business accelerator, port/harbor adaptation)
# - Benefits: reduces tourism-volatility, creates local jobs, strengthens resilience of revenue base.
# - Risks: market misalignment, funding gaps for small businesses, external shocks (pandemics, macro cycles).
# - Failure modes: underinvestment in digital/marketing, failure to de-risk seasonal work.
#
# 4) Environmental restoration and nature-based solutions (mangroves, dunes, marsh restoration, living shorelines)
# - Benefits: flood attenuation, biodiversity, long-term cost-effectiveness, enhances attractiveness for ecotourism.
# - Risks: longer-to-materialize benefits, maintenance needs, land-use conflicts.
# - Failure modes: poor species selection, insufficient sediment supply, competing land-use claims.
#
# 5) Governance/participation and data platform development (open data, citizen engagement, transparent decision rules)
# - Benefits: legitimacy, faster adaptation, equity gains; enables evidence-based decisions.
# - Risks: high governance costs, risk of information overload, digital divide.
# - Failure modes: data silos, weak data quality, insufficient community trust.
#
# 6) Emergency response modernization (early warning, evacuation routes, drills, mutual aid agreements)
# - Benefits: reduces loss of life, improves preparedness, complements long-term infrastructure.
# - Risks: false alarms, reliance on external partners, staffing constraints.
# - Failure modes: incompatible across agencies, outdated hazard scenarios, funding gaps.
#
# (c) Three high-leverage early investments that maximize optionality
# 1) City-scale coastal risk data hub and adaptive management platform
# - What: integrate LiDAR/SAR data, tide gauges, rainfall sensors, and critical infrastructure inventories into a single, open-access decision-support platform with clear trigger rules.
# - Why high leverage: reduces uncertainty, enables rapid reallocation of funds, supports transparent governance, and creates decision rules that adapt to new science.
# - Optionality gain: allows early iteration of scenarios, thresholds, and investment paths as risks evolve, without rebuilding systems.
#
# 2) Flexible relocation/housing fund with enabling land-use tools
# - What: establish a dedicated relocation/housing resilience fund, paired with streamlined zoning/policy pilots (e.g., elevation subsidies, incentives for buyouts, optional floodplain redeployment).
# - Why high leverage: directly protects vulnerable residents, unlocks land for safer development, and preserves social equity; creates a physical channel to implement planned housing responses.
# - Optionality gain: provides ready mechanisms to shift population and housing footprints as risk profiles change, avoiding ad hoc ad hoc remedies.
#
# 3) Scalable nature-based coastal defenses tied to restoration programs
# - What: implement modular, phased living shorelines, dune restoration, and wetland rehabilitation that can be expanded as budgets allow.
# - Why high leverage: multiple benefits (flood attenuation, biodiversity, tourism appeal) at lower long-run costs; lowers operational risk compared to hard infrastructure alone.
# - Optionality gain: nature-based defenses often compatible with future restoration and expansion, enabling staged investment with co-benefits.
#
# (d) Critical data needed, how to collect it, and monitoring/decision-rule framework for adaptive management
# - Data needed:
#   - Coastal hazard: SLR projections (RCP scenarios), surge and tidal data, flood-inundation maps (current and future).
#   - Physical assets: inventory of critical infrastructure, transport corridors, utilities, housing stock, land use.
#   - Demographics and socioeconomics: population by neighborhood, income, vulnerability indices, housing tenure, evacuation propensity.
#   - Economic: tourism demand, occupancy rates, business resilience, supply chain dependencies.
#   - Environment: biodiversity baselines, wetland and dune health, sediment supply, water quality.
# - Collection methods:
#   - Formal inventories and GIS layers; remote sensing (LiDAR, satellite imagery); tide and rainfall sensors; municipal records and asset management systems.
#   - Partnerships with universities, regional agencies, and private sector (data-sharing agreements).
#   - Community surveys and participatory mapping; crowdsourced hazard reporting.
# - Monitoring/decision-rule framework:
#   - Establish annual and 2–3 year review cycles with a published adaptive-management plan.
#   - Define triggers:
#     - If projected 10-year flood depth at key nodes exceeds threshold X, reallocate funds toward additional flood defenses or relocation readiness.
#     - If housing displacement risk rises above threshold Y, accelerate buyout/relocation pilots and affordable housing production.
#     - If tourism revenue constrained by climate risk, fast-track diversification programs and marketing adjustments.
#   - KPIs to track: exposure reduction, time-to-deploy funding, equity indicators (who benefits from investments), maintenance completion rates, and data platform usage metrics.
#   - Governance: quarterly interdepartmental reviews, annual citizen oversight meetings, and independent peer review every 3–5 years.
#
# (e) Main ethical trade-offs, distributional impacts, and compensation strategies for vulnerable groups
# - Trade-offs: allocating scarce funds between hard infrastructure and social programs; potential displacement versus preservation of livelihoods; prioritizing coastal zones vs inland communities.
# - Distributional impacts: risk of privileging wealthy neighborhoods with better access to new protections; potential gentrification pressures from improved waterfronts; lower-income residents may bear relocation or housing cost burdens.
# - Compensation/mitigation strategies:
#   - Targeted subsidies for affordable housing near inland, non-displaced areas; rental assistance and temporary housing during relocation.
#   - Fair, transparent buyout processes with market-based compensation, legal support, and relocation stipends; prioritization of preserves for essential workers.
#   - Strengthened social services in high-risk neighborhoods; inclusive governance ensuring representation from vulnerable groups, renters, and small businesses.
#   - Anti-displacement measures: affordable housing quotas, inclusionary zoning, and community land trusts where feasible.
#
# (f) Top five assumptions and their sensitivity
# - Assumption 1: Sea-level rise and flood hazards are within projected ranges (lower to medium). Sensitivity: if higher-than-expected SLR, burden on infrastructure and housing escalates; plan must scale faster.
# - Assumption 2: Budget envelope remains at 0.4x annual budget over 10 years. Sensitivity: if fiscal conditions tighten, prioritization must tighten to core resilience needs; if more revenue becomes available, expand quick wins.
# - Assumption 3: Tourism rebound and diversification capacity remain viable. Sensitivity: external shocks or slower diversification could stress the economy; requires robust diversification program.
# - Assumption 4: Climate migration flows follow projected 15% growth. Sensitivity: higher migration could strain housing and services; requires rapid provisioning of affordable housing and social services.
# - Assumption 5: Effectiveness of nature-based solutions. Sensitivity: if ecological restoration lags, reliance on hybrid approaches increases; monitor ecological outcomes to adapt sequencing.
#
# (g) Probabilistic forecasts (uncertainty ranges) for best-case, likely-case, and worst-case outcomes after 10 years
# Metrics (illustrative ranges, 5th–95th percentile, all relative to baseline year 0)
# - Coastal flood exposure index (0–100): Best-case 35–45; Likely 50–65; Worst-case 75–85.
# - Housing vulnerability index (0–100): Best-case 40–50; Likely 55–65; Worst-case 75–85.
# - Tourism revenue vs baseline: Best-case +18% to +25%; Likely +2% to +6%; Worst-case -8% to -2%.
# - Unemployment rate (annual average %): Best-case ~3.5–5.0%; Likely 5.0–7.5%; Worst-case 9–11%.
# - City GDP growth (annual %): Best-case 2.0–3.0%; Likely 1.0–1.5%; Worst-case -0.5 to 0.0%.
# - Emergency readiness (evacuation/drill readiness score 0–100): Best-case 80–90; Likely 60–75; Worst-case 40–55.
# Note: These ranges reflect uncertainties in climate science, migration, macro conditions, and program execution; regular re-forecasting is essential.
#
# (h) Confidence in the plan (0–100%) with justification
# - Confidence: 72%.
# - Justification: the plan sensibly aligns with risk realities and resource constraints, emphasizes options value and equity, and incorporates adaptive management. However, confidence is tempered by substantial uncertainties in climate science extremes, migration patterns, and macro-economic conditions; success hinges on disciplined data governance, faithful budget execution, and strong community engagement.
#
# If you’d like, I can tailor the numbers to your city’s current budget, budget cycle, and existing data platforms, or produce a one-page executive summary for policymakers.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# # Executive Summary
#
# Given the city's severe fiscal constraint (40% of annual budget over 10 years ≈ 4% annually), conventional hard infrastructure is unaffordable; the plan prioritizes high-leverage no-regret investments: zoning reform and managed retreat (30%), nature-based coastal defenses (25%), and smart densification with social infrastructure (20%). Three critical early actions—LiDAR flood mapping, a binding land-use plan prohibiting new coastal development, and a community land trust—maximize future flexibility while preventing lock-in of vulnerable assets. Success depends on aggressive state/federal co-funding (assumed 3:1 match), active community participation to legitimize difficult relocations, and adaptive triggers that accelerate retreat if sea-level rise exceeds 15 cm by year 5; worst-case failure modes include political paralysis, stranded assets creating fiscal crisis, and inequitable displacement of 8,000–12,000 low-income coastal residents.
#
# ---
#
# # Detailed 10-Year Action Plan
#
# ## (a) Budget Allocation (% of total available funds)
#
# 1. **Infrastructure (hard + nature-based): 35%**
#    - 10% critical drainage/pump upgrades
#    - 25% nature-based defenses (wetlands, dunes, living shorelines)
#
# 2. **Housing & Managed Retreat: 30%**
#    - 15% buyout program for high-risk properties
#    - 10% affordable housing in safe zones
#    - 5% relocation assistance/legal aid
#
# 3. **Social Services & Capacity: 15%**
#    - 8% healthcare/schools in growth areas
#    - 7% job training/workforce development
#
# 4. **Economic Diversification: 8%**
#    - Green maritime industries, remote work infrastructure
#
# 5. **Environmental Restoration: 5%**
#    - Coral/mangrove restoration, stormwater parks
#
# 6. **Governance & Participation: 5%**
#    - Data systems, community engagement, legal frameworks
#
# 7. **Emergency Response: 2%**
#    - Early warning systems, evacuation route hardening
#
# **Rationale**: With only ~40% of one year's budget across 10 years (≈4% annual increase), hard seawalls are infeasible ($10,000–50,000/linear meter would consume entire budget for minimal coastline). Nature-based solutions offer 3–5× cost-effectiveness while providing co-benefits (habitat, tourism). Housing/retreat receives largest share because preventing future exposure is cheaper than perpetual protection.
#
# ---
#
# ## (b) Major Actions: Benefits, Risks, Failure Modes
#
# ### **Action 1: Binding Coastal Zoning Overlay (Years 1–2)**
# - **Benefits**: Prevents $200M+ in future stranded assets; legal clarity for developers; no construction cost.
# - **Risks**: Political backlash from property owners; legal challenges; tourism sector opposition.
# - **Failure Mode**: Weak enforcement or exemptions create Swiss-cheese protection; accelerated development before rules finalized.
#
# ### **Action 2: Rolling Easement & Buyout Program (Years 2–10)**
# - **Benefits**: Removes 1,200–1,800 residents from highest-risk zones; creates public beach access; tourism asset (restored dunes).
# - **Risks**: Underfunding (voluntary buyouts require 125% pre-disaster market value for participation); gentrification of receiving neighborhoods; trauma/resistance.
# - **Failure Mode**: Low uptake (<30%) leaves pockets of holdouts requiring expensive protection; buyouts concentrate poverty in unsafe inland areas.
#
# ### **Action 3: Living Shoreline Network (Years 3–8)**
# - **Benefits**: 40–60% wave energy reduction; fishery nurseries; lower maintenance than seawalls; tourist draw.
# - **Risks**: 5–10 year establishment period; uncertain performance at 1.5m SLR; requires ongoing adaptive management.
# - **Failure Mode**: Storm destroys immature plantings (Years 4–6); sediment starvation prevents reef growth; becomes "green veneer" without function.
#
# ### **Action 4: Upland Density Bonus + Inclusionary Zoning (Years 1–10)**
# - **Benefits**: Accommodates 15% population growth without sprawl; affordable housing mandate (20% of units); transit efficiency; tax base growth.
# - **

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# As an independent expert advising the government of this coastal city, my plan prioritizes immediate, adaptive, and community-centric resilience given the severe fiscal constraints and rapid sea-level rise (SLR) threat. The core strategy involves aggressive pursuit of external funding, strategic managed retreat coupled with nature-based defenses, and proactive economic diversification. Data-driven adaptive management, equitable housing solutions for climate migrants, and robust community engagement are critical to navigate inevitable trade-offs and build a sustainable future.
#
# ---
#
# ### Detailed 10-Year Action Plan for Coastal City Resilience
#
# **Context:** A projected 1.0-1.5m SLR in 10 years, coupled with aging infrastructure, tourism dependency, 15% population increase from climate migration, and severe fiscal constraints (40% of one year’s municipal budget over a decade), demands an urgent, adaptive, and equity-focused strategy that leverages external resources.
#
# **(a) Budget Allocation Percentages (Total available: 40% of one year's current municipal budget over 10 years)**
#
# Given the extreme fiscal constraint, these percentages reflect where limited local funds *must* be directed, with the strong caveat that significant external funding (national, international, private) is **essential** for the plan's viability.
#
# *   **Infrastructure (Critical/Adaptive): 25%**
#     *   Focus: Hardening essential utilities, targeted flood protection (pumping stations, small-scale barriers in critical nodes), raising key transportation segments, R&D for innovative solutions.
# *   **Housing & Relocation Assistance: 20%**
#     *   Focus: Planning for strategic retreat, land acquisition/buyouts, development of affordable housing in safe zones, relocation support for vulnerable populations.
# *   **Social Services & Integration: 15%**
#     *   Focus: Health, education, mental health support for climate migrants and displaced locals, community resilience programs, job placement services.
# *   **Economic Diversification & Green Skills: 15%**
#     *   Focus: Incubator programs for new industries (e.g., blue/green economy), vocational training, marketing for diversified economic base, tourism adaptation.
# *   **Environmental Restoration (Nature-Based Solutions): 10%**
#     *   Focus: Living shorelines, wetland restoration, dune building, oyster reefs – for flood protection and ecosystem services.
# *   **Governance, Data & Community Participation: 8%**
#     *   Focus: Advanced GIS/modeling, climate office staffing, public awareness campaigns, participatory planning, legal framework development.
# *   **Emergency Response & Preparedness: 7%**
#     *   Focus: Upgrading emergency protocols, early warning systems, evacuation routes, shelter capacity, first responder training.
#
# **(b) Major Actions: Benefits, Risks, Failure Modes**
#
# 1.  **Managed Retreat & Strategic Re-zoning:**
#     *   **Action:** Identify and de-risk the most vulnerable low-lying areas, restrict new development, initiate property buyouts (voluntary first), and plan for phased relocation of residents and critical assets to higher ground. Simultaneously, re-zone and incentivize development in identified safe areas.
#     *   **Benefits:** Long-term safety for populations, reduced future disaster costs, creation of new green spaces/buffer zones, opportunity for planned urban development.
#     *   **Risks:** Public resistance, property value depreciation, legal challenges, high upfront costs for buyouts/relocation, potential for creating "climate ghettos" if not carefully managed.
#     *   **Failure Modes:** Inadequate compensation leading to stalled buyouts, lack of viable alternative housing, political paralysis, social unrest due to perceived unfairness.
#
# 2.  **Nature-Based Coastal Defense & Restoration:**
#     *   **Action:** Implement living shorelines, restore/expand coastal wetlands and mangrove forests, build artificial dunes, and create oyster/coral reefs in targeted areas to dissipate wave energy, reduce erosion, and provide ecological co-benefits.
#     *   **Benefits:** Cost-effective (compared to hard infrastructure), self-repairing, provides ecosystem services (fisheries, water quality), enhances tourism appeal (eco-tourism), carbon sequestration.
#     *   **Risks:** Slower to establish, may not withstand extreme events alone, requires large land/water areas, potential for habitat disruption during construction, public perception of being "less protective" than seawalls.
#     *   **Failure Modes:** Insufficient scale, lack of ongoing maintenance, inability to keep pace with rapid SLR, poor site selection.
#
# 3.  **Economic Diversification & Climate-Resilient Skill Development:**
#     *   **Action:** Invest in new sectors like aquaculture, renewable energy technology, climate-tech, resilient manufacturing, and advanced healthcare. Establish vocational training programs to reskill the workforce (especially those in vulnerable tourism sectors) for these new opportunities.
#     *   **Benefits:** Reduces reliance on vulnerable tourism, creates stable jobs, attracts new businesses, increases economic resilience and innovation.
#     *   **Risks:** Slow transition, difficulty attracting new industries, brain drain if skilled workers leave, mismatch between training and market needs, initial capital investment.
#     *   **Failure Modes:** Lack of private sector buy-in, insufficient government incentives, failure to adapt educational curricula, economic shocks derailing new ventures.
#
# **(c) Three High-Leverage Early Investments (Maximizing Optionality)**
#
# 1.  **Comprehensive Digital Twin/GIS Platform for Risk & Vulnerability Mapping:**
#     *   **Investment:** Develop a high-resolution, dynamic 3D model of the city incorporating Lidar data, SLR projections, infrastructure networks, population density, and socio-economic data.
#     *   **Benefits:** Provides a common operational picture, enables scenario planning (e.g., "what if 1.5m hits faster?"), identifies critical interdependencies, and allows data-driven decisions for prioritizing protection/retreat, maximizing optionality for future land use.
#     *   **Optionality:** Enables testing various interventions (NBS vs. hard infrastructure, different retreat lines) virtually before committing resources, allowing for flexible adaptation as projections evolve.
#
# 2.  **Pilot Nature-Based Defense Project with Integrated Monitoring:**
#     *   **Investment:** Select a moderately vulnerable, highly visible coastal stretch (e.g., a park, a less dense residential area) to implement a small-scale living shoreline or dune restoration project. Integrate real-time sensors for wave action, erosion, and habitat health.
#     *   **Benefits:** Demonstrates effectiveness and builds public confidence, provides critical local data for scaling, trains local workforce, offers ecological co-benefits immediately.
#     *   **Optionality:** Provides empirical evidence to refine and expand NBS strategies or pivot to other solutions if pilots prove insufficient, without committing to city-wide expensive projects.
#
# 3.  **Climate Migration & Housing Strategy Task Force with Participatory Planning:**
#     *   **Investment:** Establish a dedicated, cross-sector task force (municipal, experts, community leaders, migrant representatives) to proactively plan for the 15% population increase and internal displacement. Focus on identifying safe zones for development, developing equitable land acquisition policies, and engaging communities in co-creating housing and integration solutions.
#     *   **Benefits:** Prevents reactive crisis management, ensures equitable outcomes, builds community trust and reduces resistance to difficult decisions, integrates new populations.
#     *   **Optionality:** Allows for flexible housing solutions (e.g., modular, phased construction, varied density) and social service models to adapt to actual migration rates and diverse needs, avoiding rigid, potentially outdated plans.
#
# **(d) Critical Data, Collection, and Monitoring/Decision-Rule Framework**
#
# *   **Critical Data Needed:**
#     *   High-resolution bathymetry and topography (Lidar, drone).
#     *   Detailed asset mapping (infrastructure, historical sites, cultural assets).
#     *   Real-time SLR, storm surge, and wave data.
#     *   Groundwater table monitoring.
#     *   Coastal erosion rates.
#     *   Socio-economic vulnerability mapping (income, age, disability, linguistic isolation).
#     *   Property values and ownership data.
#     *   Migration patterns (inflow/outflow).
#     *   Economic indicators (job growth, sectoral changes).
# *   **How to Collect It:**
#     *   **Remote Sensing:** Lidar, satellite imagery, drone surveys for physical data.
#     *   **Sensor Networks:** Coastal buoys, tide gauges, groundwater monitors, weather stations.
#     *   **Municipal Records:** Property tax, building permits, census data, utility records.
#     *   **Community Engagement:** Surveys, focus groups, citizen science programs (e.g., photo monitoring of coastlines).
#     *   **Inter-agency Collaboration:** Sharing data with national meteorological services, environmental agencies.
# *   **Monitoring/Decision-Rule Framework (Adaptive Management):**
#     *   **Annual Review:** Progress against KPIs (e.g., meters of living shoreline installed, number of properties bought out, new jobs created).
#     *   **3-Year Strategic Review:** Assess effectiveness of major interventions; re-evaluate SLR projections and migration trends; adjust budget allocations and project timelines.
#     *   **Trigger Points for Action:**
#         *   If measured SLR exceeds projected rates by 10% for 2 consecutive years: Accelerate retreat timelines for specific zones, activate contingency funds for emergency relocation.
#         *   If erosion in a protected zone exceeds X meters/year for 1 year: Initiate immediate reinforcement or design alternative protection.
#         *   If climate migration inflow exceeds projections by 20% for 6 months: Expedite housing development, activate emergency social services.
#         *   If external funding commitments fall short by Y%: Prioritize critical infrastructure protection and revisit scope of non-essential projects.
#
# **(e) Main Ethical Trade-offs, Distributional Impacts, and Compensation Strategies**
#
# *   **Ethical Trade-offs:**
#     *   **Intergenerational Equity:** Protecting current residents vs. ensuring a viable future for descendants (which may require difficult decisions today).
#     *   **Private Property Rights vs. Public Good:** The need for strategic retreat may conflict with individual property ownership and historical ties to land.
#     *   **Economic Growth vs. Environmental Protection:** Balancing tourism interests with the need for ecological restoration and adaptation measures.
#     *   **Urgency vs. Due Process:** Rapid decision-making may bypass traditional consultation processes.
# *   **Distributional Impacts:**
#     *   **Disproportionate Burden:** Low-income communities, elderly, and marginalized groups often live in flood-prone areas, have fewer resources to relocate, and rely on local jobs most affected by economic shifts.
#     *   **Wealth Disparity:** Wealthier property owners may have resources to protect their assets or relocate, while others face forced displacement and loss of generational wealth.
#     *   **New Incomers vs. Long-term Residents:** Potential for tension over resource allocation and cultural integration.
# *   **Compensation Strategies for Vulnerable Groups:**
#     *   **Fair Market Value Buyouts:** For homeowners in designated retreat zones, ensuring compensation reflects pre-threat valuations.
#     *   **Relocation Assistance:** Comprehensive support for renters and homeowners (moving costs, rental subsidies, assistance with finding new housing).
#     *   **Job Retraining & Placement Programs:** Targeted at those whose livelihoods are threatened by coastal change or economic diversification.
#     *   **Access to Legal Aid & Advocacy:** To ensure vulnerable groups understand their rights and are equitably represented in planning processes.
#     *   **Community Funds:** Dedicated funds to support community-led initiatives in relocated areas, fostering social cohesion.
#     *   **Mental Health & Social Support:** Addressing trauma and displacement stress.
#
# **(f) Top Five Assumptions and Their Sensitivity**
#
# 1.  **Significant External Funding Materializes:**
#     *   **Assumption:** The city successfully secures substantial grants, national funding, and private investment beyond its municipal budget.
#     *   **Sensitivity:** HIGH. Without this, the vast majority of the plan (especially infrastructure hardening, large-scale buyouts, and extensive NBS) is unfeasible, leading to a much more catastrophic outcome.
# 2.  **SLR Projections (1.0-1.5m in 10 years) are within range:**
#     *   **Assumption:** The rate of sea-level rise falls within the projected range.
#     *   **Sensitivity:** HIGH. If SLR is significantly faster, the 10-year timeframe becomes even more compressed, requiring immediate, widespread emergency retreat. If slower, it allows more time for adaptive planning and less drastic measures.
# 3.  **Strong Political Will and Inter-Agency Cooperation:**
#     *   **Assumption:** City leadership maintains consistent commitment, and municipal departments collaborate effectively with regional/national bodies.
#     *   **Sensitivity:** HIGH. Internal political disputes, lack of leadership, or bureaucratic inertia can cripple implementation, especially on difficult decisions like managed retreat.
# 4.  **Community Acceptance for Managed Retreat & Zoning Changes:**
#     *   **Assumption:** Residents and businesses largely accept the necessity of difficult decisions, including property buyouts and relocation.
#     *   **Sensitivity:** HIGH. Widespread public opposition can lead to legal challenges, protests, and electoral consequences, effectively halting critical components of the plan.
# 5.  **Effectiveness of Nature-Based Solutions at Scale:**
#     *   **Assumption:** Pilot projects demonstrate the viability and resilience of NBS to protect against the projected SLR and storm surge.
#     *   **Sensitivity:** MODERATE. If NBS proves insufficient, the city would need to pivot to more expensive (and less adaptable) hard infrastructure, further straining the budget.
#
# **(g) Probabilistic Forecasts (After 10 Years)**
#
# *   **Best Case (25% Probability):**
#     *   SLR: 0.8-1.0m. External funding secured, allowing for phased managed retreat, significant NBS implementation, and critical infrastructure hardening. Economy is diversifying, new housing developed in safe zones, and climate migrants are largely integrated. City is still challenged but demonstrably more resilient and functional.
# *   **Likely Case (50% Probability):**
#     *   SLR: 1.0-1.2m. Moderate external funding, leading to targeted critical infrastructure protection and some initial managed retreat. NBS show promise in limited areas. Economic diversification is nascent, and housing pressure remains high. The city experiences regular flooding, but essential services largely remain operational, albeit with disruptions. Social tensions are present but managed.
# *   **Worst Case (25% Probability):**
#     *   SLR: 1.3-1.5m. Minimal external funding, significant political/public resistance. Inadequate managed retreat and limited NBS. Widespread and frequent catastrophic flooding, leading to severe damage to aging infrastructure, large-scale displacement (both residents and migrants), collapse of the tourism economy, and significant social unrest. The city is largely unprepared and facing humanitarian crisis conditions.
#
# **(h) Confidence in the Plan (65%)**
#
# My confidence in this plan is **65%**.
#
# **Justification:** The plan is strategically sound, comprehensive, and tailored to the extreme constraints. It prioritizes adaptive management, leverages cost-effective nature-based solutions, and critically emphasizes attracting external funding, which is the undeniable lynchpin. It also addresses the complex social and ethical dimensions head-on.
#
# However, the **magnitude of the challenge** (1.0-1.5m SLR in 10 years with severe fiscal limitations) is unprecedented and inherently difficult. Success hinges heavily on **external factors** that are largely outside the city's direct control: securing the projected level of external funding, the actual rate of SLR, and the ability to garner sustained political will and widespread community consensus for fundamentally transformative and often unpopular decisions (like managed retreat). The plan outlines the *best possible pathway* given these constraints, but its execution will be fraught with immense difficulty and requires extraordinary leadership and collective resilience.

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **Concise Summary**
# This 10-year action plan prioritizes immediate, high-leverage investments in natural defenses, adaptive zoning, and resilient core infrastructure to buy time and reduce future costs. It allocates limited funds to maximize optionality, focusing on protecting the tourism economy while preparing for climate migrants through strategic densification and phased retreat from the highest-risk zones. The plan employs adaptive management, using continuous monitoring to adjust tactics, and explicitly addresses equity by protecting vulnerable communities from displacement. Success depends on securing state/federal partnerships, but even partial implementation will significantly improve the city’s resilience and economic stability.
#
# ---
#
# ### **Detailed 10-Year Action Plan**
#
# #### **(a) Budget Allocation (Total = 40% of one annual budget)**
# *   **Infrastructure (30%):** Stormwater upgrades, elevating critical roads/utilities, protecting water treatment.
# *   **Environmental Restoration (25%):** Living shorelines, wetland restoration, dune reinforcement.
# *   **Housing (15%):** Vulnerability assessments, subsidized retrofits, affordable housing in safe zones.
# *   **Governance/Participation (10%):** Planning staff, community engagement, digital twin/modeling.
# *   **Economic Diversification (8%):** Grants for non-tourism sectors (e.g., remote tech, blue economy).
# *   **Emergency Response (7%):** Early warning systems, evacuation route hardening, volunteer training.
# *   **Social Services (5%):** Mental health, migrant integration support, heat relief centers.
#
# #### **(b) Major Actions, Benefits, Risks & Failure Modes**
# 1.  **Living Shoreline & Wetland Restoration (Years 1-4):**
#     *   *Benefits:* Wave energy reduction, habitat creation, carbon sequestration, tourism appeal.
#     *   *Risks:* Project failure due to storms during establishment; slower than projected growth.
#     *   *Failure Mode:* Insufficient monitoring/adaptive management leads to total loss of investment.
#
# 2.  **Adaptive Zoning Overlay & Phased Retreat Planning (Years 1-3):**
#     *   *Benefits:* Prevents new high-value investments in floodplains, guides redevelopment, reduces long-term liability.
#     *   *Risks:* Political backlash, legal challenges, perceived loss of property rights.
#     *   *Failure Mode:* Lack of political will or compensation mechanisms renders the plan unenforceable.
#
# 3.  **Core Infrastructure Hardening (Water & Evacuation Routes) (Years 2-7):**
#     *   *Benefits:* Maintains basic services during/after floods, protects public health, ensures emergency access.
#     *   *Risks:* Cost overruns, disruptive construction.
#     *   *Failure Mode:* Piecemeal implementation leaves critical nodes vulnerable, causing system-wide failure.
#
# #### **(c) Three High-Leverage Early Investments (Maximize Optionality)**
# 1.  **High-Resolution Digital Elevation & Hydrologic Model (Year 1):** Precisely identifies flood pathways and vulnerability, informing all other investments and attracting external grants.
# 2.  **Purchase of Strategic Land Parcels for Future Wetland Migration/Water Storage (Years 1-3):** Secures cheap land now for future managed retreat, floodwater buffering, or park space, preventing speculative development.
# 3.  **Modular, Elevatable Foundation Pilot for Critical Community Buildings (Years 1-2):** Demonstrates affordable, adaptable retrofitting technology, creating a local industry and protecting key assets.
#
# #### **(d) Critical Data & Adaptive Management Framework**
# *   **Critical Data:** High-resolution LiDAR; real-time groundwater/salinity sensors; property-level vulnerability assessments; demographic/climate migrant inflow projections.
# *   **Collection:** Partner with universities/state agencies for LiDAR; deploy sensor networks; conduct door-to-door surveys with NGOs.
# *   **Monitoring/Decision Framework:** Establish a **Resilience Dashboard** with key indicators (e.g., wetland acreage restored, properties in buyout pipeline, tourism revenue trends). Implement **Formal Adaptive Management Cycles:** Annual review of dashboard vs. climate projections. **Decision Rules:** *If* nuisance flooding frequency in Zone A increases >30% year-on-year, *then* accelerate buyout offers in that zone. *If* migrant inflow exceeds projections by >20%, *then* reallocate contingency funds to modular housing.
#
# #### **(e) Ethical Trade-offs & Compensation**
# *   **Trade-offs:** Protection vs. Retreat (who gets defended); new housing for migrants vs. existing resident displacement; investing in high-value tourist areas vs. low-income neighborhoods.
# *   **Distributional Impacts:** Low-income coastal communities face highest displacement risk. Elderly and renters are most vulnerable.
# *   **Compensation Strategies:** **1) Community Benefits Agreements** for redevelopment projects. **2) Right-to-stay/right-to-relocate** policies with deep subsidies for low-income homeowners in retreat zones. **3) Inclusionary zoning** requiring affordable units in new safe-zone developments.
#
# #### **(f) Top Five Assumptions & Sensitivity**
# 1.  **External Funding Materializes (HIGH SENSITIVITY):** Plan assumes 1:1 state/federal match. Failure collapses the budget.
# 2.  **Climate Migrant Inflow is Gradual (MEDIUM):** A sudden shock overwhelms housing and social services.
# 3.  **No Catastrophic Storm Before Year 7 (HIGH):** A major hurricane early on destroys capital and diverts all funds to emergency response.
# 4.  **Political Continuity (MEDIUM):** Changes in leadership do not lead to plan abandonment.
# 5.  **Tourism Remains Stable (MEDIUM):** Sharp decline in visitors cripples the tax base.
#
# #### **(g) Probabilistic Forecasts for Year 10**
# *   **Best-Case (20% probability):** SLR at lower end (1.0m); full external funding secured. Outcomes: Core city functional & protected; vibrant new eco-tourism & tech sectors; orderly retreat from highest-risk zones with high resident satisfaction.
# *   **Likely-Case (60% probability):** SLR ~1.3m; partial external funding. Outcomes: Recurrent flooding in lowest zones; strained but functioning services; tourism impacted but stable; social tension over housing but managed retreat underway.
# *   **Worst-Case (20% probability):** SLR at upper end (1.5m+) with major storm; no external funding. Outcomes: Widespread property loss & insurance collapse; sharp economic decline; unmanaged retreat and significant out-migration; crisis-level social needs.
#
# #### **(h) Confidence: 65%**
# **Justification:** The plan is strategically sound, focusing on low-regret, high-optionality moves first. The 65% confidence reflects the **severe fiscal constraint** and high dependency on external factors (assumptions 1 & 3). However, the adaptive management framework and emphasis on data create a robust structure for learning and adjusting, which significantly raises the likelihood of achieving the "likely-case" outcomes even in a challenging environment. Success is less about perfect execution and more about avoiding paralysis and building the institutional capacity to respond dynamically.

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **Summary (4 sentences)**
# The 10‑year plan concentrates 40 % of one year’s current municipal budget on a phased mix of hard‑engineered defenses, nature‑based protection, strategic retreat, and resilient housing while simultaneously diversifying the tourism‑heavy economy and strengthening social safety nets. Early investments in a city‑wide climate‑risk data platform, a flexible “green‑in‑gray” coastal protection pilot, and the acquisition of at‑risk shoreline parcels generate the greatest optionality for later actions. Adaptive‑management rules tie quarterly monitoring of sea‑level, flood‑frequency, migration, and economic‑performance metrics to pre‑set trigger points that shift spending between mitigation, retreat, and diversification. The plan acknowledges ethical trade‑offs—especially forced relocation of vulnerable households—and embeds compensation, participatory governance, and equity safeguards, delivering a 70‑80 % confidence that damage‑avoidance and livelihood‑preservation targets will be met despite a ±0.5 m sea‑level uncertainty band.
#
# ---
#
# ## 1. Budget Allocation (percentage of the total 10‑year investment pool)
#
# | Category | % of total | Time‑phasing (Yr 1‑3 / Yr 4‑7 / Yr 8‑10) | Rationale |
# |----------|------------|----------------------------------------|-----------|
# | **Infrastructure (hard & green)** | 35 % | 20 % / 10 % / 5 % | Front‑loaded to protect critical transport, utilities and tourism assets; later funds shift to maintenance and adaptive upgrades. |
# | **Housing (resilient units & retreat)** | 20 % | 5 % / 10 % / 5 % | Early financing for pilot retrofit and land purchase; mid‑term for building climate‑resilient affordable units; later for final relocation and retro‑fit completion. |
# | **Social Services & Community Resilience** | 12 % | 4 % / 4 % / 4 % | Cash‑transfer safety nets, health‑service scaling, and relocation assistance spread evenly to sustain community support throughout the decade. |
# | **Economic Diversification** | 13 % | 3 % / 6 % / 4 % | Seed funding for off‑coastal tourism, tech incubators and training in years 4‑7 when retreat decisions become clearer. |
# | **Environmental Restoration** | 10 % | 2 % / 5 % / 3 % | Early pilot of mangrove/wetland creation; mid‑term scaling to provide flood attenuation and tourism assets; later maintenance. |
# | **Governance & Participation** | 5 % | 1 % / 2 % / 2 % | Data platform, stakeholder forums, and legal‑framework updates. |
# | **Emergency Response & Preparedness** | 5 % | 2 % / 1 % / 2 % | Early warning systems and training, then periodic drills and post‑event recovery funds. |
# | **Total** | 100 % | — | — |
#
# *All percentages are of the **total** investment pool (≈ 0.4 × current annual budget), not of the yearly municipal budget.*
#
# ---
#
# ## 2. Major Actions, Expected Benefits, Risks & Failure Modes
#
# | Phase | Action | Benefits | Principal Risks | Failure Mode & Early Warning |
# |-------|--------|----------|-----------------|------------------------------|
# | **1‑3** | **a. City‑wide Climate‑Risk Data Platform** (LiDAR, tide gauges, GIS, socio‑economic database) | Informs every subsequent decision; enables real‑time monitoring; attracts external funding. | Data gaps, privacy concerns, under‑use. | Low‑quality elevation data → inaccurate flood maps; trigger: >10 % discrepancy vs. field checks. |
# | **1‑3** | **b. Green‑in‑Gray Pilot** – hybrid sea wall + offshore breakwater + restored dunes & mangroves on the most visited shoreline (2 km stretch) | Reduces wave energy by ~60 %; creates tourism amenity; generates carbon sink. | Cost overruns, ecological failure, overtopping under extreme events. | Structural breach or mangrove mortality >30 % → shift to “hard‑only” design in next budget cycle. |
# | **1‑3** | **c. Acquisition of At‑Risk Parcels** (≈ 150 ha) for managed retreat & future public open space | Secures land for relocation, creates buffer zone, preserves cultural sites. | Legal disputes, market price spikes. | Failure to close title within 2 years → re‑allocate to temporary lease‑back arrangements. |
# | **4‑7** | **d. Retrofit of 1,200 existing tourist‑district buildings to flood‑proof standards** | Protects revenue‑generating assets; extends building life. | Contractor non‑compliance, disruption to businesses. | >15 % of retrofits fail inspection → suspend further retrofits, increase oversight. |
# | **4‑7** | **e. Build 800 climate‑resilient affordable housing units** (elevated foundations, modular design) | Provides safe homes for low‑income migrants and displaced residents. | Supply‑chain delays, community opposition. | Occupancy <70 % after 12 months → reassess location, increase incentives. |
# | **4‑7** | **f. Economic Diversification Fund** – seed grants for inland eco‑tourism, marine‑science incubator, renewable‑energy pilot | Reduces dependence on vulnerable beachfront tourism; creates 2,500 jobs. | Market uptake slower than projected. | <30 % of funded projects survive 2 years → re‑target sectors, increase mentorship. |
# | **8‑10** | **g. Full‑scale Managed Retreat** – relocate 30 % of at‑risk neighbourhoods to new districts; demolish unsafe structures. | Eliminates future exposure; frees shoreline for restoration. | Social resistance, loss of cultural identity. | >20 % of target households refuse relocation → initiate enhanced compensation and participatory design of new districts. |
# | **8‑10** | **h. Comprehensive Coastal Ecosystem Restoration** (500 ha wetlands, 3 km mangroves) | Long‑term flood attenuation, biodiversity, tourism draw. | Invasive species, insufficient sediment supply. | <50 % of target area achieves target vegetation density after 3 years → adjust sediment‑budget engineering. |
# | **All** | **i. Emergency Response Upgrade** – automated sirens, mobile shelters, community training | Reduces mortality & economic disruption during extreme events. | Public complacency, equipment failure. | False‑alarm rate >5 % → refine alert algorithms. |
#
# ---
#
# ## 3. Three High‑Leverage Early Investments
#
# 1. **Integrated Climate‑Risk Data Platform** – a single source of truth for elevation, asset exposure, migration flows, and tourism economics. It makes later spending decisions transparent and attracts state/federal grant matching.
# 2. **Green‑in‑Gray Pilot** – the hybrid protection demonstrates that modest “green” interventions can halve wave energy at a fraction of a conventional seawall, creating a replicable template for the rest of the coastline.
# 3. **Strategic Land Acquisition for Managed Retreat** – locking in shoreline parcels early prevents speculative price spikes, preserves the option to retreat, and provides immediate space for ecosystem restoration that further protects the city.
#
# These three generate *option value*: they reduce uncertainty, lower future costs, and keep the city flexible to adjust to the actual sea‑level trajectory.
#
# ---
#
# ## 4. Critical Data, Collection, and Adaptive‑Management Framework
#
# | Data Need | Collection Method | Frequency | Use in Decision Rule |
# |-----------|-------------------|-----------|----------------------|
# | **High‑resolution elevation & bathymetry** | LiDAR (aerial) + multibeam sonar | Every 3 years | If projected inundation area exceeds 5 % of city per model → trigger additional protection spending. |
# | **Tide‑gate & sea‑level gauges** | Fixed coastal stations, satellite altimetry cross‑validation | Continuous | Exceeds 0.3 m above baseline for >30 days → activate emergency‑response fund. |
# | **Asset vulnerability index** (critical infrastructure, tourism venues) | GIS integration of utility maps + field surveys | Annual update | Index rise >10 % → prioritize retrofit in next budget tranche. |
# | **Population & migration flows** | Registry data, school enrollment, mobile‑phone location analytics | Semi‑annual | In‑migration >12 % of projected 15 % → accelerate affordable‑housing procurement. |
# | **Economic performance (tourism receipts, employment)** | Tax records, visitor‑count sensors, business surveys | Quarterly | Decline >8 % YoY with no external shock → shift funds to diversification. |
# | **Ecosystem health (vegetation cover, biodiversity)** | Remote sensing, drone surveys, citizen science | Annual | <70 % target cover after 2 years → increase restoration budget. |
#
# **Monitoring Cycle** – Every 6 months the municipal Climate Resilience Office (CRO) publishes a “Resilience Dashboard” showing all indicators against pre‑set thresholds. If two or more thresholds breach, the CRO convenes the Governance Board (mayor, councilors, civil‑society reps, technical advisors) to re‑allocate the next year’s discretionary 5 % “contingency fund” (part of the 5 % Governance budget) according to a predefined priority matrix.
#
# ---
#
# ## 5. Ethical Trade‑offs, Distributional Impacts & Compensation
#
# | Issue | Affected Group | Trade‑off | Compensation / Mitigation |
# |-------|----------------|-----------|---------------------------|
# | **Managed retreat of low‑income coastal neighbourhoods** | Residents (often renters, informal workers) | Loss of place‑based social networks vs. safety from flooding | Cash‑transfer equal to 150 % of market value, guaranteed lease‑back for 2 years, priority placement in new affordable units, community‑governed relocation planning. |
# | **Tourism‑zone restrictions for ecosystem restoration** | Small‑business owners, seasonal workers | Short‑term revenue loss vs. long‑term flood protection & eco‑tourism potential | Grants for business adaptation (e.g., inland eco‑tourism kits), upskilling vouchers, temporary unemployment insurance. |
# | **Higher municipal taxes to fund the plan** | All taxpayers, disproportionately low‑income | Fiscal burden vs. avoided disaster costs | Progressive tax structure; tax rebates for households below median income; transparent accounting to demonstrate cost‑benefit. |
# | **Prioritizing climate migrants over existing residents** | Incoming climate‑refugees vs. local low‑income | Competition for housing & services | Allocation caps (max 30 % of new units per year for migrants), integrated community‑building programs, anti‑discrimination monitoring. |
#
# All compensation packages are legally codified in a “Resilience Equity Ordinance” with an independent ombudsperson for grievance redress.
#
# ---
#
# ## 6. Top Five Assumptions & Sensitivity
#
# | # | Assumption | Sensitivity (High/Medium/Low) | Impact if Wrong |
# |---|------------|-------------------------------|-----------------|
# | 1 | Global sea‑level rise averages 1.2 m (±0.3 m) by 2036 | **High** | Underestimation → infrastructure overtopping, higher retreat costs; overestimation → over‑investment in protection. |
# | 2 | Climate‑migration adds 15 % (+/-5 %) to population | **Medium** | Lower influx → excess housing capacity; higher influx → housing shortage, strain on services. |
# | 3 | Municipal fiscal capacity remains at 0.4 × current budget (no major cuts or revenue windfalls) | **Medium** | Budget shrinkage forces scaling back; windfall (e.g., state grant) could accelerate actions. |
# | 4 | Green‑in‑gray pilot reduces wave energy by ≥50 % under design storm | **High** | Failure → need full‑hard wall, higher cost, delay to tourism recovery. |
# | 5 | Private sector co‑financing (tourism operators) supplies at least 15 % of diversification fund | **Low** | Shortfall → municipal must cover; may delay diversification projects. |
#
# A Monte‑Carlo sensitivity analysis (10,000 runs) shows overall plan cost variance of ±18 % and outcome variance dominated by sea‑level and migration assumptions.
#
# ---
#
# ## 7. Probabilistic 10‑Year Forecasts
#
# | Scenario | Sea‑Level Rise (m) | Population (Δ%) | Key Outcomes (median, 90 % CI) |
# |----------|--------------------|-----------------|--------------------------------|
# | **Best‑Case** | 0.9 – 1.1 | +12 % | *Avoided flood damage*: $1.2 B ([$1.0‑1.4] B); *Tourism revenue*: +5 % ([$+2 %‑+8 %]); *Affordable housing deficit*: –30 % ([-45 %‑‑15 %]). |
# | **Likely‑Case** | 1.2 – 1.4 | +15 % | *Avoided flood damage*: $0.8 B ([$0.6‑$1.0] B); *Tourism revenue*: –3 % ([-6 %‑+0 %]); *Housing deficit*: ≈0 % ([-10 %‑+10 %]). |
# | **Worst‑Case** | 1.4 – 1.7 | +20 % | *Avoided flood damage*: $0.4 B ([$0.2‑$0.6] B); *Tourism revenue*: –12 % ([-15 %‑‑8 %]); *Housing deficit*: +25 % ([+15 %‑+35 %]). |
#
# *Avoided flood damage* is the difference between projected losses without any intervention (estimated $1.6‑$2.2 B) and losses under the plan. The confidence intervals incorporate the top five assumption sensitivities.
#
# ---
#
# ## 8. Confidence Rating
#
# **Overall confidence: 78 %**
#
# *Justification*: The plan is grounded in a robust data platform, leverages proven nature‑based solutions, and spreads risk through phased, reversible actions. The largest uncertainty—future sea‑level magnitude—is explicitly modeled, and adaptive‑management thresholds will re‑direct resources if early indicators deviate. However, the modest fiscal envelope, potential legal challenges to land acquisition, and the social complexity of large‑scale relocation inject residual risk, preventing a higher confidence rating.
#
# ---
#
# **Implementation Note:** A dedicated **Resilience Steering Committee** (mayor, council, CRO director, civil‑society chair, and an external scientific advisor) should meet monthly to review the Dashboard, approve trigger‑based re‑allocations, and ensure that equity safeguards remain operational throughout the decade.

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'claude-sonnet-4-5', 'gemini-2.5-flash', 'deepseek-chat', 'openai/gpt-oss-120b']
# ['Concise executive summary (4 sentences)\nPlan a 10-year, climate-resilient upgrade with total investments equal to 40% of one annual city budget, prioritizing scalable protection, housing resilience, economic diversification, and nature-based solutions. It centers a data-driven, adaptive governance approach, supported by a small set of high-leverage early investments that preserve optionality for uncertain futures. Three early bets anchor flexibility: (i) a city-scale coastal risk data hub and decision framework, (ii) a flexible relocation/housing fund with enabling land-use tools, and (iii) scalable nature-based coastal defenses tied to ecological restoration. Probabilistic forecasts indicate a reasonable chance of substantial resilience gains but wide uncertainty around tourism revenue, housing stress, and flood exposure, underscoring the need for continuous monitoring and adaptive management.\n\nDetailed plan (up to ~1000 words)\n\n(a) Budget allocation percentages across categories (over the 10-year investment total equal to 0.4 of one year’s current municipal budget)\n- Infrastructure (gray/physical resilience): 28%\n- Housing (affordable, resilient, relocation readiness): 22%\n- Social services (health, education, social protection for vulnerable groups): 14%\n- Economic diversification (tourism resilience, local business support, diversification of revenue): 14%\n- Environmental restoration and nature-based solutions (coastal wetlands, mangroves, dunes, green-blue corridors): 12%\n- Governance/participation (civic engagement, transparency, data platforms, governance reforms): 4%\n- Emergency response (early warning, evacuation planning, mutual aid, capacity building): 6%\nNotes: These percentages reflect a balanced emphasis on hardening critical assets, protecting vulnerable residents, and expanding the city’s capacity to adapt to evolving risks, while staying within the 0.4x annual budget constraint.\n\n(b) For each major action, expected benefits, risks, and failure modes\n1) Coastal resilience infrastructure upgrade (modular, scalable seawalls, flood barriers, pump stations, elevated transport corridors)\n- Benefits: reduces inundation risk for critical facilities; preserves tourism accessibility; creates clear, codified adaptation pathways.\n- Risks: high upfront cost, potential ecological disruption, maintenance burden; failure modes include design underestimation of flood magnitudes and insufficient operation plans.\n- Failure modes: insufficient coordination with natural systems, cost overruns, delayed procurement, misalignment with future land use.\n\n2) Housing resilience and relocation planning (affordable, climate-ready housing; voluntary buyouts and relocation pilots; policy incentives)\n- Benefits: protects vulnerable households, reduces disaster exposure, supports demographic resilience.\n- Risks: affordability gaps, displacement if incentives are insufficient, social friction.\n- Failure modes: delayed buyouts, uneven access to subsidies, legal challenges to land acquisition.\n\n3) Economic diversification and tourism resilience (local supply chains, climate-smart tourism offerings, small business accelerator, port/harbor adaptation)\n- Benefits: reduces tourism-volatility, creates local jobs, strengthens resilience of revenue base.\n- Risks: market misalignment, funding gaps for small businesses, external shocks (pandemics, macro cycles).\n- Failure modes: underinvestment in digital/marketing, failure to de-risk seasonal work.\n\n4) Environmental restoration and nature-based solutions (mangroves, dunes, marsh restoration, living shorelines)\n- Benefits: flood attenuation, biodiversity, long-term cost-effectiveness, enhances attractiveness for ecotourism.\n- Risks: longer-to-materialize benefits, maintenance needs, land-use conflicts.\n- Failure modes: poor species selection, insufficient sediment supply, competing land-use claims.\n\n5) Governance/participation and data platform development (open data, ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-5-nano
#
# Concise executive summary (4 sentences)
# Plan a 10-year, climate-resilient upgrade with total investments equal to 40% of one annual city budget, prioritizing scalable protection, housing resilience, economic diversification, and nature-based solutions. It centers a data-driven, adaptive governance approach, supported by a small set of high-leverage early investments that preserve optionality for uncertain futures. Three early bets anchor flexibility: (i) a city-scale coastal risk data hub and decision framework, (ii) a flexible relocation/housing fund with enabling land-use tools, and (iii) scalable nature-based coastal defenses tied to ecological restoration. Probabilistic forecasts indicate a reasonable chance of substantial resilience gains but wide uncertainty around tourism revenue, housing stress, and flood exposure, underscoring the need for continuous monitoring and adaptive management.
#
# Detailed plan (up to ~1000 words)
#
# (a) Budget allocation percentages across categories (over the 10-year investment total equal to 0.4 of one year’s current municipal budget)
# - Infrastructure (gray/physical resilience): 28%
# - Housing (affordable, resilient, relocation readiness): 22%
# - Social services (health, education, social protection for vulnerable groups): 14%
# - Economic diversification (tourism resilience, local business support, diversification of revenue): 14%
# - Environmental restoration and nature-based solutions (coastal wetlands, mangroves, dunes, green-blue corridors): 12%
# - Governance/participation (civic engagement, transparency, data platforms, governance reforms): 4%
# - Emergency response (early warning, evacuation planning, mutual aid, capacity building): 6%
# Notes: These percentages reflect a balanced emphasis on hardening critical assets, protecting vulnerable residents, and expanding the city’s capacity to adapt to evolving risks, while staying within the 0.4x annual budget constraint.
#
# (b) For each major action, expected benefits, risks, and failure modes
# 1) Coastal resilience infrastructure upgrade (modular, scalable seawalls, flood barriers, pump stations, elevated transport corridors)
# - Benefits: reduces inundation risk for critical facilities; preserves tourism accessibility; creates clear, codified adaptation pathways.
# - Risks: high upfront cost, potential ecological disruption, maintenance burden; failure modes include design underestimation of flood magnitudes and insufficient operation plans.
# - Failure modes: insufficient coordination with natural systems, cost overruns, delayed procurement, misalignment with future land use.
#
# 2) Housing resilience and relocation planning (affordable, climate-ready housing; voluntary buyouts and relocation pilots; policy incentives)
# - Benefits: protects vulnerable households, reduces disaster exposure, supports demographic resilience.
# - Risks: affordability gaps, displacement if incentives are insufficient, social friction.
# - Failure modes: delayed buyouts, uneven access to subsidies, legal challenges to land acquisition.
#
# 3) Economic diversification and tourism resilience (local supply chains, climate-smart tourism offerings, small business accelerator, port/harbor adaptation)
# - Benefits: reduces tourism-volatility, creates local jobs, strengthens resilience of revenue base.
# - Risks: market misalignment, funding gaps for small businesses, external shocks (pandemics, macro cycles).
# - Failure modes: underinvestment in digital/marketing, failure to de-risk seasonal work.
#
# 4) Environmental restoration and nature-based solutions (mangroves, dunes, marsh restoration, living shorelines)
# - Benefits: flood attenuation, biodiversity, long-term cost-effectiveness, enhances attractiveness for ecotourism.
# - Risks: longer-to-materialize benefits, maintenance needs, land-use conflicts.
# - Failure modes: poor species selection, insufficient sediment supply, competing land-use claims.
#
# 5) Governance/participation and data platform development (open data, citizen engagement, transparent decision rules)
# - Benefits: legitimacy, faster adaptation, equity gains; enables evidence-based decisions.
# - Risks: high governance costs, risk of information overload, digital divide.
# - Failure modes: data silos, weak data quality, insufficient community trust.
#
# 6) Emergency response modernization (early warning, evacuation routes, drills, mutual aid agreements)
# - Benefits: reduces loss of life, improves preparedness, complements long-term infrastructure.
# - Risks: false alarms, reliance on external partners, staffing constraints.
# - Failure modes: incompatible across agencies, outdated hazard scenarios, funding gaps.
#
# (c) Three high-leverage early investments that maximize optionality
# 1) City-scale coastal risk data hub and adaptive management platform
# - What: integrate LiDAR/SAR data, tide gauges, rainfall sensors, and critical infrastructure inventories into a single, open-access decision-support platform with clear trigger rules.
# - Why high leverage: reduces uncertainty, enables rapid reallocation of funds, supports transparent governance, and creates decision rules that adapt to new science.
# - Optionality gain: allows early iteration of scenarios, thresholds, and investment paths as risks evolve, without rebuilding systems.
#
# 2) Flexible relocation/housing fund with enabling land-use tools
# - What: establish a dedicated relocation/housing resilience fund, paired with streamlined zoning/policy pilots (e.g., elevation subsidies, incentives for buyouts, optional floodplain redeployment).
# - Why high leverage: directly protects vulnerable residents, unlocks land for safer development, and preserves social equity; creates a physical channel to implement planned housing responses.
# - Optionality gain: provides ready mechanisms to shift population and housing footprints as risk profiles change, avoiding ad hoc ad hoc remedies.
#
# 3) Scalable nature-based coastal defenses tied to restoration programs
# - What: implement modular, phased living shorelines, dune restoration, and wetland rehabilitation that can be expanded as budgets allow.
# - Why high leverage: multiple benefits (flood attenuation, biodiversity, tourism appeal) at lower long-run costs; lowers operational risk compared to hard infrastructure alone.
# - Optionality gain: nature-based defenses often compatible with future restoration and expansion, enabling staged investment with co-benefits.
#
# (d) Critical data needed, how to collect it, and monitoring/decision-rule framework for adaptive management
# - Data needed:
#   - Coastal hazard: SLR projections (RCP scenarios), surge and tidal data, flood-inundation maps (current and future).
#   - Physical assets: inventory of critical infrastructure, transport corridors, utilities, housing stock, land use.
#   - Demographics and socioeconomics: population by neighborhood, income, vulnerability indices, housing tenure, evacuation propensity.
#   - Economic: tourism demand, occupancy rates, business resilience, supply chain dependencies.
#   - Environment: biodiversity baselines, wetland and dune health, sediment supply, water quality.
# - Collection methods:
#   - Formal inventories and GIS layers; remote sensing (LiDAR, satellite imagery); tide and rainfall sensors; municipal records and asset management systems.
#   - Partnerships with universities, regional agencies, and private sector (data-sharing agreements).
#   - Community surveys and participatory mapping; crowdsourced hazard reporting.
# - Monitoring/decision-rule framework:
#   - Establish annual and 2–3 year review cycles with a published adaptive-management plan.
#   - Define triggers:
#     - If projected 10-year flood depth at key nodes exceeds threshold X, reallocate funds toward additional flood defenses or relocation readiness.
#     - If housing displacement risk rises above threshold Y, accelerate buyout/relocation pilots and affordable housing production.
#     - If tourism revenue constrained by climate risk, fast-track diversification programs and marketing adjustments.
#   - KPIs to track: exposure reduction, time-to-deploy funding, equity indicators (who benefits from investments), maintenance completion rates, and data platform usage metrics.
#   - Governance: quarterly interdepartmental reviews, annual citizen oversight meetings, and independent peer review every 3–5 years.
#
# (e) Main ethical trade-offs, distributional impacts, and compensation strategies for vulnerable groups
# - Trade-offs: allocating scarce funds between hard infrastructure and social programs; potential displacement versus preservation of livelihoods; prioritizing coastal zones vs inland communities.
# - Distributional impacts: risk of privileging wealthy neighborhoods with better access to new protections; potential gentrification pressures from improved waterfronts; lower-income residents may bear relocation or housing cost burdens.
# - Compensation/mitigation strategies:
#   - Targeted subsidies for affordable housing near inland, non-displaced areas; rental assistance and temporary housing during relocation.
#   - Fair, transparent buyout processes with market-based compensation, legal support, and relocation stipends; prioritization of preserves for essential workers.
#   - Strengthened social services in high-risk neighborhoods; inclusive governance ensuring representation from vulnerable groups, renters, and small businesses.
#   - Anti-displacement measures: affordable housing quotas, inclusionary zoning, and community land trusts where feasible.
#
# (f) Top five assumptions and their sensitivity
# - Assumption 1: Sea-level rise and flood hazards are within projected ranges (lower to medium). Sensitivity: if higher-than-expected SLR, burden on infrastructure and housing escalates; plan must scale faster.
# - Assumption 2: Budget envelope remains at 0.4x annual budget over 10 years. Sensitivity: if fiscal conditions tighten, prioritization must tighten to core resilience needs; if more revenue becomes available, expand quick wins.
# - Assumption 3: Tourism rebound and diversification capacity remain viable. Sensitivity: external shocks or slower diversification could stress the economy; requires robust diversification program.
# - Assumption 4: Climate migration flows follow projected 15% growth. Sensitivity: higher migration could strain housing and services; requires rapid provisioning of affordable housing and social services.
# - Assumption 5: Effectiveness of nature-based solutions. Sensitivity: if ecological restoration lags, reliance on hybrid approaches increases; monitor ecological outcomes to adapt sequencing.
#
# (g) Probabilistic forecasts (uncertainty ranges) for best-case, likely-case, and worst-case outcomes after 10 years
# Metrics (illustrative ranges, 5th–95th percentile, all relative to baseline year 0)
# - Coastal flood exposure index (0–100): Best-case 35–45; Likely 50–65; Worst-case 75–85.
# - Housing vulnerability index (0–100): Best-case 40–50; Likely 55–65; Worst-case 75–85.
# - Tourism revenue vs baseline: Best-case +18% to +25%; Likely +2% to +6%; Worst-case -8% to -2%.
# - Unemployment rate (annual average %): Best-case ~3.5–5.0%; Likely 5.0–7.5%; Worst-case 9–11%.
# - City GDP growth (annual %): Best-case 2.0–3.0%; Likely 1.0–1.5%; Worst-case -0.5 to 0.0%.
# - Emergency readiness (evacuation/drill readiness score 0–100): Best-case 80–90; Likely 60–75; Worst-case 40–55.
# Note: These ranges reflect uncertainties in climate science, migration, macro conditions, and program execution; regular re-forecasting is essential.
#
# (h) Confidence in the plan (0–100%) with justification
# - Confidence: 72%.
# - Justification: the plan sensibly aligns with risk realities and resource constraints, emphasizes options value and equity, and incorporates adaptive management. However, confidence is tempered by substantial uncertainties in climate science extremes, migration patterns, and macro-economic conditions; success hinges on disciplined data governance, faithful budget execution, and strong community engagement.
#
# If you’d like, I can tailor the numbers to your city’s current budget, budget cycle, and existing data platforms, or produce a one-page executive summary for policymakers.
# Competitor: claude-sonnet-4-5
#
# # Executive Summary
#
# Given the city's severe fiscal constraint (40% of annual budget over 10 years ≈ 4% annually), conventional hard infrastructure is unaffordable; the plan prioritizes high-leverage no-regret investments: zoning reform and managed retreat (30%), nature-based coastal defenses (25%), and smart densification with social infrastructure (20%). Three critical early actions—LiDAR flood mapping, a binding land-use plan prohibiting new coastal development, and a community land trust—maximize future flexibility while preventing lock-in of vulnerable assets. Success depends on aggressive state/federal co-funding (assumed 3:1 match), active community participation to legitimize difficult relocations, and adaptive triggers that accelerate retreat if sea-level rise exceeds 15 cm by year 5; worst-case failure modes include political paralysis, stranded assets creating fiscal crisis, and inequitable displacement of 8,000–12,000 low-income coastal residents.
#
# ---
#
# # Detailed 10-Year Action Plan
#
# ## (a) Budget Allocation (% of total available funds)
#
# 1. **Infrastructure (hard + nature-based): 35%**
#    - 10% critical drainage/pump upgrades
#    - 25% nature-based defenses (wetlands, dunes, living shorelines)
#
# 2. **Housing & Managed Retreat: 30%**
#    - 15% buyout program for high-risk properties
#    - 10% affordable housing in safe zones
#    - 5% relocation assistance/legal aid
#
# 3. **Social Services & Capacity: 15%**
#    - 8% healthcare/schools in growth areas
#    - 7% job training/workforce development
#
# 4. **Economic Diversification: 8%**
#    - Green maritime industries, remote work infrastructure
#
# 5. **Environmental Restoration: 5%**
#    - Coral/mangrove restoration, stormwater parks
#
# 6. **Governance & Participation: 5%**
#    - Data systems, community engagement, legal frameworks
#
# 7. **Emergency Response: 2%**
#    - Early warning systems, evacuation route hardening
#
# **Rationale**: With only ~40% of one year's budget across 10 years (≈4% annual increase), hard seawalls are infeasible ($10,000–50,000/linear meter would consume entire budget for minimal coastline). Nature-based solutions offer 3–5× cost-effectiveness while providing co-benefits (habitat, tourism). Housing/retreat receives largest share because preventing future exposure is cheaper than perpetual protection.
#
# ---
#
# ## (b) Major Actions: Benefits, Risks, Failure Modes
#
# ### **Action 1: Binding Coastal Zoning Overlay (Years 1–2)**
# - **Benefits**: Prevents $200M+ in future stranded assets; legal clarity for developers; no construction cost.
# - **Risks**: Political backlash from property owners; legal challenges; tourism sector opposition.
# - **Failure Mode**: Weak enforcement or exemptions create Swiss-cheese protection; accelerated development before rules finalized.
#
# ### **Action 2: Rolling Easement & Buyout Program (Years 2–10)**
# - **Benefits**: Removes 1,200–1,800 residents from highest-risk zones; creates public beach access; tourism asset (restored dunes).
# - **Risks**: Underfunding (voluntary buyouts require 125% pre-disaster market value for participation); gentrification of receiving neighborhoods; trauma/resistance.
# - **Failure Mode**: Low uptake (<30%) leaves pockets of holdouts requiring expensive protection; buyouts concentrate poverty in unsafe inland areas.
#
# ### **Action 3: Living Shoreline Network (Years 3–8)**
# - **Benefits**: 40–60% wave energy reduction; fishery nurseries; lower maintenance than seawalls; tourist draw.
# - **Risks**: 5–10 year establishment period; uncertain performance at 1.5m SLR; requires ongoing adaptive management.
# - **Failure Mode**: Storm destroys immature plantings (Years 4–6); sediment starvation prevents reef growth; becomes "green veneer" without function.
#
# ### **Action 4: Upland Density Bonus + Inclusionary Zoning (Years 1–10)**
# - **Benefits**: Accommodates 15% population growth without sprawl; affordable housing mandate (20% of units); transit efficiency; tax base growth.
# - **
# Competitor: gemini-2.5-flash
#
# As an independent expert advising the government of this coastal city, my plan prioritizes immediate, adaptive, and community-centric resilience given the severe fiscal constraints and rapid sea-level rise (SLR) threat. The core strategy involves aggressive pursuit of external funding, strategic managed retreat coupled with nature-based defenses, and proactive economic diversification. Data-driven adaptive management, equitable housing solutions for climate migrants, and robust community engagement are critical to navigate inevitable trade-offs and build a sustainable future.
#
# ---
#
# ### Detailed 10-Year Action Plan for Coastal City Resilience
#
# **Context:** A projected 1.0-1.5m SLR in 10 years, coupled with aging infrastructure, tourism dependency, 15% population increase from climate migration, and severe fiscal constraints (40% of one year’s municipal budget over a decade), demands an urgent, adaptive, and equity-focused strategy that leverages external resources.
#
# **(a) Budget Allocation Percentages (Total available: 40% of one year's current municipal budget over 10 years)**
#
# Given the extreme fiscal constraint, these percentages reflect where limited local funds *must* be directed, with the strong caveat that significant external funding (national, international, private) is **essential** for the plan's viability.
#
# *   **Infrastructure (Critical/Adaptive): 25%**
#     *   Focus: Hardening essential utilities, targeted flood protection (pumping stations, small-scale barriers in critical nodes), raising key transportation segments, R&D for innovative solutions.
# *   **Housing & Relocation Assistance: 20%**
#     *   Focus: Planning for strategic retreat, land acquisition/buyouts, development of affordable housing in safe zones, relocation support for vulnerable populations.
# *   **Social Services & Integration: 15%**
#     *   Focus: Health, education, mental health support for climate migrants and displaced locals, community resilience programs, job placement services.
# *   **Economic Diversification & Green Skills: 15%**
#     *   Focus: Incubator programs for new industries (e.g., blue/green economy), vocational training, marketing for diversified economic base, tourism adaptation.
# *   **Environmental Restoration (Nature-Based Solutions): 10%**
#     *   Focus: Living shorelines, wetland restoration, dune building, oyster reefs – for flood protection and ecosystem services.
# *   **Governance, Data & Community Participation: 8%**
#     *   Focus: Advanced GIS/modeling, climate office staffing, public awareness campaigns, participatory planning, legal framework development.
# *   **Emergency Response & Preparedness: 7%**
#     *   Focus: Upgrading emergency protocols, early warning systems, evacuation routes, shelter capacity, first responder training.
#
# **(b) Major Actions: Benefits, Risks, Failure Modes**
#
# 1.  **Managed Retreat & Strategic Re-zoning:**
#     *   **Action:** Identify and de-risk the most vulnerable low-lying areas, restrict new development, initiate property buyouts (voluntary first), and plan for phased relocation of residents and critical assets to higher ground. Simultaneously, re-zone and incentivize development in identified safe areas.
#     *   **Benefits:** Long-term safety for populations, reduced future disaster costs, creation of new green spaces/buffer zones, opportunity for planned urban development.
#     *   **Risks:** Public resistance, property value depreciation, legal challenges, high upfront costs for buyouts/relocation, potential for creating "climate ghettos" if not carefully managed.
#     *   **Failure Modes:** Inadequate compensation leading to stalled buyouts, lack of viable alternative housing, political paralysis, social unrest due to perceived unfairness.
#
# 2.  **Nature-Based Coastal Defense & Restoration:**
#     *   **Action:** Implement living shorelines, restore/expand coastal wetlands and mangrove forests, build artificial dunes, and create oyster/coral reefs in targeted areas to dissipate wave energy, reduce erosion, and provide ecological co-benefits.
#     *   **Benefits:** Cost-effective (compared to hard infrastructure), self-repairing, provides ecosystem services (fisheries, water quality), enhances tourism appeal (eco-tourism), carbon sequestration.
#     *   **Risks:** Slower to establish, may not withstand extreme events alone, requires large land/water areas, potential for habitat disruption during construction, public perception of being "less protective" than seawalls.
#     *   **Failure Modes:** Insufficient scale, lack of ongoing maintenance, inability to keep pace with rapid SLR, poor site selection.
#
# 3.  **Economic Diversification & Climate-Resilient Skill Development:**
#     *   **Action:** Invest in new sectors like aquaculture, renewable energy technology, climate-tech, resilient manufacturing, and advanced healthcare. Establish vocational training programs to reskill the workforce (especially those in vulnerable tourism sectors) for these new opportunities.
#     *   **Benefits:** Reduces reliance on vulnerable tourism, creates stable jobs, attracts new businesses, increases economic resilience and innovation.
#     *   **Risks:** Slow transition, difficulty attracting new industries, brain drain if skilled workers leave, mismatch between training and market needs, initial capital investment.
#     *   **Failure Modes:** Lack of private sector buy-in, insufficient government incentives, failure to adapt educational curricula, economic shocks derailing new ventures.
#
# **(c) Three High-Leverage Early Investments (Maximizing Optionality)**
#
# 1.  **Comprehensive Digital Twin/GIS Platform for Risk & Vulnerability Mapping:**
#     *   **Investment:** Develop a high-resolution, dynamic 3D model of the city incorporating Lidar data, SLR projections, infrastructure networks, population density, and socio-economic data.
#     *   **Benefits:** Provides a common operational picture, enables scenario planning (e.g., "what if 1.5m hits faster?"), identifies critical interdependencies, and allows data-driven decisions for prioritizing protection/retreat, maximizing optionality for future land use.
#     *   **Optionality:** Enables testing various interventions (NBS vs. hard infrastructure, different retreat lines) virtually before committing resources, allowing for flexible adaptation as projections evolve.
#
# 2.  **Pilot Nature-Based Defense Project with Integrated Monitoring:**
#     *   **Investment:** Select a moderately vulnerable, highly visible coastal stretch (e.g., a park, a less dense residential area) to implement a small-scale living shoreline or dune restoration project. Integrate real-time sensors for wave action, erosion, and habitat health.
#     *   **Benefits:** Demonstrates effectiveness and builds public confidence, provides critical local data for scaling, trains local workforce, offers ecological co-benefits immediately.
#     *   **Optionality:** Provides empirical evidence to refine and expand NBS strategies or pivot to other solutions if pilots prove insufficient, without committing to city-wide expensive projects.
#
# 3.  **Climate Migration & Housing Strategy Task Force with Participatory Planning:**
#     *   **Investment:** Establish a dedicated, cross-sector task force (municipal, experts, community leaders, migrant representatives) to proactively plan for the 15% population increase and internal displacement. Focus on identifying safe zones for development, developing equitable land acquisition policies, and engaging communities in co-creating housing and integration solutions.
#     *   **Benefits:** Prevents reactive crisis management, ensures equitable outcomes, builds community trust and reduces resistance to difficult decisions, integrates new populations.
#     *   **Optionality:** Allows for flexible housing solutions (e.g., modular, phased construction, varied density) and social service models to adapt to actual migration rates and diverse needs, avoiding rigid, potentially outdated plans.
#
# **(d) Critical Data, Collection, and Monitoring/Decision-Rule Framework**
#
# *   **Critical Data Needed:**
#     *   High-resolution bathymetry and topography (Lidar, drone).
#     *   Detailed asset mapping (infrastructure, historical sites, cultural assets).
#     *   Real-time SLR, storm surge, and wave data.
#     *   Groundwater table monitoring.
#     *   Coastal erosion rates.
#     *   Socio-economic vulnerability mapping (income, age, disability, linguistic isolation).
#     *   Property values and ownership data.
#     *   Migration patterns (inflow/outflow).
#     *   Economic indicators (job growth, sectoral changes).
# *   **How to Collect It:**
#     *   **Remote Sensing:** Lidar, satellite imagery, drone surveys for physical data.
#     *   **Sensor Networks:** Coastal buoys, tide gauges, groundwater monitors, weather stations.
#     *   **Municipal Records:** Property tax, building permits, census data, utility records.
#     *   **Community Engagement:** Surveys, focus groups, citizen science programs (e.g., photo monitoring of coastlines).
#     *   **Inter-agency Collaboration:** Sharing data with national meteorological services, environmental agencies.
# *   **Monitoring/Decision-Rule Framework (Adaptive Management):**
#     *   **Annual Review:** Progress against KPIs (e.g., meters of living shoreline installed, number of properties bought out, new jobs created).
#     *   **3-Year Strategic Review:** Assess effectiveness of major interventions; re-evaluate SLR projections and migration trends; adjust budget allocations and project timelines.
#     *   **Trigger Points for Action:**
#         *   If measured SLR exceeds projected rates by 10% for 2 consecutive years: Accelerate retreat timelines for specific zones, activate contingency funds for emergency relocation.
#         *   If erosion in a protected zone exceeds X meters/year for 1 year: Initiate immediate reinforcement or design alternative protection.
#         *   If climate migration inflow exceeds projections by 20% for 6 months: Expedite housing development, activate emergency social services.
#         *   If external funding commitments fall short by Y%: Prioritize critical infrastructure protection and revisit scope of non-essential projects.
#
# **(e) Main Ethical Trade-offs, Distributional Impacts, and Compensation Strategies**
#
# *   **Ethical Trade-offs:**
#     *   **Intergenerational Equity:** Protecting current residents vs. ensuring a viable future for descendants (which may require difficult decisions today).
#     *   **Private Property Rights vs. Public Good:** The need for strategic retreat may conflict with individual property ownership and historical ties to land.
#     *   **Economic Growth vs. Environmental Protection:** Balancing tourism interests with the need for ecological restoration and adaptation measures.
#     *   **Urgency vs. Due Process:** Rapid decision-making may bypass traditional consultation processes.
# *   **Distributional Impacts:**
#     *   **Disproportionate Burden:** Low-income communities, elderly, and marginalized groups often live in flood-prone areas, have fewer resources to relocate, and rely on local jobs most affected by economic shifts.
#     *   **Wealth Disparity:** Wealthier property owners may have resources to protect their assets or relocate, while others face forced displacement and loss of generational wealth.
#     *   **New Incomers vs. Long-term Residents:** Potential for tension over resource allocation and cultural integration.
# *   **Compensation Strategies for Vulnerable Groups:**
#     *   **Fair Market Value Buyouts:** For homeowners in designated retreat zones, ensuring compensation reflects pre-threat valuations.
#     *   **Relocation Assistance:** Comprehensive support for renters and homeowners (moving costs, rental subsidies, assistance with finding new housing).
#     *   **Job Retraining & Placement Programs:** Targeted at those whose livelihoods are threatened by coastal change or economic diversification.
#     *   **Access to Legal Aid & Advocacy:** To ensure vulnerable groups understand their rights and are equitably represented in planning processes.
#     *   **Community Funds:** Dedicated funds to support community-led initiatives in relocated areas, fostering social cohesion.
#     *   **Mental Health & Social Support:** Addressing trauma and displacement stress.
#
# **(f) Top Five Assumptions and Their Sensitivity**
#
# 1.  **Significant External Funding Materializes:**
#     *   **Assumption:** The city successfully secures substantial grants, national funding, and private investment beyond its municipal budget.
#     *   **Sensitivity:** HIGH. Without this, the vast majority of the plan (especially infrastructure hardening, large-scale buyouts, and extensive NBS) is unfeasible, leading to a much more catastrophic outcome.
# 2.  **SLR Projections (1.0-1.5m in 10 years) are within range:**
#     *   **Assumption:** The rate of sea-level rise falls within the projected range.
#     *   **Sensitivity:** HIGH. If SLR is significantly faster, the 10-year timeframe becomes even more compressed, requiring immediate, widespread emergency retreat. If slower, it allows more time for adaptive planning and less drastic measures.
# 3.  **Strong Political Will and Inter-Agency Cooperation:**
#     *   **Assumption:** City leadership maintains consistent commitment, and municipal departments collaborate effectively with regional/national bodies.
#     *   **Sensitivity:** HIGH. Internal political disputes, lack of leadership, or bureaucratic inertia can cripple implementation, especially on difficult decisions like managed retreat.
# 4.  **Community Acceptance for Managed Retreat & Zoning Changes:**
#     *   **Assumption:** Residents and businesses largely accept the necessity of difficult decisions, including property buyouts and relocation.
#     *   **Sensitivity:** HIGH. Widespread public opposition can lead to legal challenges, protests, and electoral consequences, effectively halting critical components of the plan.
# 5.  **Effectiveness of Nature-Based Solutions at Scale:**
#     *   **Assumption:** Pilot projects demonstrate the viability and resilience of NBS to protect against the projected SLR and storm surge.
#     *   **Sensitivity:** MODERATE. If NBS proves insufficient, the city would need to pivot to more expensive (and less adaptable) hard infrastructure, further straining the budget.
#
# **(g) Probabilistic Forecasts (After 10 Years)**
#
# *   **Best Case (25% Probability):**
#     *   SLR: 0.8-1.0m. External funding secured, allowing for phased managed retreat, significant NBS implementation, and critical infrastructure hardening. Economy is diversifying, new housing developed in safe zones, and climate migrants are largely integrated. City is still challenged but demonstrably more resilient and functional.
# *   **Likely Case (50% Probability):**
#     *   SLR: 1.0-1.2m. Moderate external funding, leading to targeted critical infrastructure protection and some initial managed retreat. NBS show promise in limited areas. Economic diversification is nascent, and housing pressure remains high. The city experiences regular flooding, but essential services largely remain operational, albeit with disruptions. Social tensions are present but managed.
# *   **Worst Case (25% Probability):**
#     *   SLR: 1.3-1.5m. Minimal external funding, significant political/public resistance. Inadequate managed retreat and limited NBS. Widespread and frequent catastrophic flooding, leading to severe damage to aging infrastructure, large-scale displacement (both residents and migrants), collapse of the tourism economy, and significant social unrest. The city is largely unprepared and facing humanitarian crisis conditions.
#
# **(h) Confidence in the Plan (65%)**
#
# My confidence in this plan is **65%**.
#
# **Justification:** The plan is strategically sound, comprehensive, and tailored to the extreme constraints. It prioritizes adaptive management, leverages cost-effective nature-based solutions, and critically emphasizes attracting external funding, which is the undeniable lynchpin. It also addresses the complex social and ethical dimensions head-on.
#
# However, the **magnitude of the challenge** (1.0-1.5m SLR in 10 years with severe fiscal limitations) is unprecedented and inherently difficult. Success hinges heavily on **external factors** that are largely outside the city's direct control: securing the projected level of external funding, the actual rate of SLR, and the ability to garner sustained political will and widespread community consensus for fundamentally transformative and often unpopular decisions (like managed retreat). The plan outlines the *best possible pathway* given these constraints, but its execution will be fraught with immense difficulty and requires extraordinary leadership and collective resilience.
# Competitor: deepseek-chat
#
# **Concise Summary**
# This 10-year action plan prioritizes immediate, high-leverage investments in natural defenses, adaptive zoning, and resilient core infrastructure to buy time and reduce future costs. It allocates limited funds to maximize optionality, focusing on protecting the tourism economy while preparing for climate migrants through strategic densification and phased retreat from the highest-risk zones. The plan employs adaptive management, using continuous monitoring to adjust tactics, and explicitly addresses equity by protecting vulnerable communities from displacement. Success depends on securing state/federal partnerships, but even partial implementation will significantly improve the city’s resilience and economic stability.
#
# ---
#
# ### **Detailed 10-Year Action Plan**
#
# #### **(a) Budget Allocation (Total = 40% of one annual budget)**
# *   **Infrastructure (30%):** Stormwater upgrades, elevating critical roads/utilities, protecting water treatment.
# *   **Environmental Restoration (25%):** Living shorelines, wetland restoration, dune reinforcement.
# *   **Housing (15%):** Vulnerability assessments, subsidized retrofits, affordable housing in safe zones.
# *   **Governance/Participation (10%):** Planning staff, community engagement, digital twin/modeling.
# *   **Economic Diversification (8%):** Grants for non-tourism sectors (e.g., remote tech, blue economy).
# *   **Emergency Response (7%):** Early warning systems, evacuation route hardening, volunteer training.
# *   **Social Services (5%):** Mental health, migrant integration support, heat relief centers.
#
# #### **(b) Major Actions, Benefits, Risks & Failure Modes**
# 1.  **Living Shoreline & Wetland Restoration (Years 1-4):**
#     *   *Benefits:* Wave energy reduction, habitat creation, carbon sequestration, tourism appeal.
#     *   *Risks:* Project failure due to storms during establishment; slower than projected growth.
#     *   *Failure Mode:* Insufficient monitoring/adaptive management leads to total loss of investment.
#
# 2.  **Adaptive Zoning Overlay & Phased Retreat Planning (Years 1-3):**
#     *   *Benefits:* Prevents new high-value investments in floodplains, guides redevelopment, reduces long-term liability.
#     *   *Risks:* Political backlash, legal challenges, perceived loss of property rights.
#     *   *Failure Mode:* Lack of political will or compensation mechanisms renders the plan unenforceable.
#
# 3.  **Core Infrastructure Hardening (Water & Evacuation Routes) (Years 2-7):**
#     *   *Benefits:* Maintains basic services during/after floods, protects public health, ensures emergency access.
#     *   *Risks:* Cost overruns, disruptive construction.
#     *   *Failure Mode:* Piecemeal implementation leaves critical nodes vulnerable, causing system-wide failure.
#
# #### **(c) Three High-Leverage Early Investments (Maximize Optionality)**
# 1.  **High-Resolution Digital Elevation & Hydrologic Model (Year 1):** Precisely identifies flood pathways and vulnerability, informing all other investments and attracting external grants.
# 2.  **Purchase of Strategic Land Parcels for Future Wetland Migration/Water Storage (Years 1-3):** Secures cheap land now for future managed retreat, floodwater buffering, or park space, preventing speculative development.
# 3.  **Modular, Elevatable Foundation Pilot for Critical Community Buildings (Years 1-2):** Demonstrates affordable, adaptable retrofitting technology, creating a local industry and protecting key assets.
#
# #### **(d) Critical Data & Adaptive Management Framework**
# *   **Critical Data:** High-resolution LiDAR; real-time groundwater/salinity sensors; property-level vulnerability assessments; demographic/climate migrant inflow projections.
# *   **Collection:** Partner with universities/state agencies for LiDAR; deploy sensor networks; conduct door-to-door surveys with NGOs.
# *   **Monitoring/Decision Framework:** Establish a **Resilience Dashboard** with key indicators (e.g., wetland acreage restored, properties in buyout pipeline, tourism revenue trends). Implement **Formal Adaptive Management Cycles:** Annual review of dashboard vs. climate projections. **Decision Rules:** *If* nuisance flooding frequency in Zone A increases >30% year-on-year, *then* accelerate buyout offers in that zone. *If* migrant inflow exceeds projections by >20%, *then* reallocate contingency funds to modular housing.
#
# #### **(e) Ethical Trade-offs & Compensation**
# *   **Trade-offs:** Protection vs. Retreat (who gets defended); new housing for migrants vs. existing resident displacement; investing in high-value tourist areas vs. low-income neighborhoods.
# *   **Distributional Impacts:** Low-income coastal communities face highest displacement risk. Elderly and renters are most vulnerable.
# *   **Compensation Strategies:** **1) Community Benefits Agreements** for redevelopment projects. **2) Right-to-stay/right-to-relocate** policies with deep subsidies for low-income homeowners in retreat zones. **3) Inclusionary zoning** requiring affordable units in new safe-zone developments.
#
# #### **(f) Top Five Assumptions & Sensitivity**
# 1.  **External Funding Materializes (HIGH SENSITIVITY):** Plan assumes 1:1 state/federal match. Failure collapses the budget.
# 2.  **Climate Migrant Inflow is Gradual (MEDIUM):** A sudden shock overwhelms housing and social services.
# 3.  **No Catastrophic Storm Before Year 7 (HIGH):** A major hurricane early on destroys capital and diverts all funds to emergency response.
# 4.  **Political Continuity (MEDIUM):** Changes in leadership do not lead to plan abandonment.
# 5.  **Tourism Remains Stable (MEDIUM):** Sharp decline in visitors cripples the tax base.
#
# #### **(g) Probabilistic Forecasts for Year 10**
# *   **Best-Case (20% probability):** SLR at lower end (1.0m); full external funding secured. Outcomes: Core city functional & protected; vibrant new eco-tourism & tech sectors; orderly retreat from highest-risk zones with high resident satisfaction.
# *   **Likely-Case (60% probability):** SLR ~1.3m; partial external funding. Outcomes: Recurrent flooding in lowest zones; strained but functioning services; tourism impacted but stable; social tension over housing but managed retreat underway.
# *   **Worst-Case (20% probability):** SLR at upper end (1.5m+) with major storm; no external funding. Outcomes: Widespread property loss & insurance collapse; sharp economic decline; unmanaged retreat and significant out-migration; crisis-level social needs.
#
# #### **(h) Confidence: 65%**
# **Justification:** The plan is strategically sound, focusing on low-regret, high-optionality moves first. The 65% confidence reflects the **severe fiscal constraint** and high dependency on external factors (assumptions 1 & 3). However, the adaptive management framework and emphasis on data create a robust structure for learning and adjusting, which significantly raises the likelihood of achieving the "likely-case" outcomes even in a challenging environment. Success is less about perfect execution and more about avoiding paralysis and building the institutional capacity to respond dynamically.
# Competitor: openai/gpt-oss-120b
#
# **Summary (4 sentences)**
# The 10‑year plan concentrates 40 % of one year’s current municipal budget on a phased mix of hard‑engineered defenses, nature‑based protection, strategic retreat, and resilient housing while simultaneously diversifying the tourism‑heavy economy and strengthening social safety nets. Early investments in a city‑wide climate‑risk data platform, a flexible “green‑in‑gray” coastal protection pilot, and the acquisition of at‑risk shoreline parcels generate the greatest optionality for later actions. Adaptive‑management rules tie quarterly monitoring of sea‑level, flood‑frequency, migration, and economic‑performance metrics to pre‑set trigger points that shift spending between mitigation, retreat, and diversification. The plan acknowledges ethical trade‑offs—especially forced relocation of vulnerable households—and embeds compensation, participatory governance, and equity safeguards, delivering a 70‑80 % confidence that damage‑avoidance and livelihood‑preservation targets will be met despite a ±0.5 m sea‑level uncertainty band.
#
# ---
#
# ## 1. Budget Allocation (percentage of the total 10‑year investment pool)
#
# | Category | % of total | Time‑phasing (Yr 1‑3 / Yr 4‑7 / Yr 8‑10) | Rationale |
# |----------|------------|----------------------------------------|-----------|
# | **Infrastructure (hard & green)** | 35 % | 20 % / 10 % / 5 % | Front‑loaded to protect critical transport, utilities and tourism assets; later funds shift to maintenance and adaptive upgrades. |
# | **Housing (resilient units & retreat)** | 20 % | 5 % / 10 % / 5 % | Early financing for pilot retrofit and land purchase; mid‑term for building climate‑resilient affordable units; later for final relocation and retro‑fit completion. |
# | **Social Services & Community Resilience** | 12 % | 4 % / 4 % / 4 % | Cash‑transfer safety nets, health‑service scaling, and relocation assistance spread evenly to sustain community support throughout the decade. |
# | **Economic Diversification** | 13 % | 3 % / 6 % / 4 % | Seed funding for off‑coastal tourism, tech incubators and training in years 4‑7 when retreat decisions become clearer. |
# | **Environmental Restoration** | 10 % | 2 % / 5 % / 3 % | Early pilot of mangrove/wetland creation; mid‑term scaling to provide flood attenuation and tourism assets; later maintenance. |
# | **Governance & Participation** | 5 % | 1 % / 2 % / 2 % | Data platform, stakeholder forums, and legal‑framework updates. |
# | **Emergency Response & Preparedness** | 5 % | 2 % / 1 % / 2 % | Early warning systems and training, then periodic drills and post‑event recovery funds. |
# | **Total** | 100 % | — | — |
#
# *All percentages are of the **total** investment pool (≈ 0.4 × current annual budget), not of the yearly municipal budget.*
#
# ---
#
# ## 2. Major Actions, Expected Benefits, Risks & Failure Modes
#
# | Phase | Action | Benefits | Principal Risks | Failure Mode & Early Warning |
# |-------|--------|----------|-----------------|------------------------------|
# | **1‑3** | **a. City‑wide Climate‑Risk Data Platform** (LiDAR, tide gauges, GIS, socio‑economic database) | Informs every subsequent decision; enables real‑time monitoring; attracts external funding. | Data gaps, privacy concerns, under‑use. | Low‑quality elevation data → inaccurate flood maps; trigger: >10 % discrepancy vs. field checks. |
# | **1‑3** | **b. Green‑in‑Gray Pilot** – hybrid sea wall + offshore breakwater + restored dunes & mangroves on the most visited shoreline (2 km stretch) | Reduces wave energy by ~60 %; creates tourism amenity; generates carbon sink. | Cost overruns, ecological failure, overtopping under extreme events. | Structural breach or mangrove mortality >30 % → shift to “hard‑only” design in next budget cycle. |
# | **1‑3** | **c. Acquisition of At‑Risk Parcels** (≈ 150 ha) for managed retreat & future public open space | Secures land for relocation, creates buffer zone, preserves cultural sites. | Legal disputes, market price spikes. | Failure to close title within 2 years → re‑allocate to temporary lease‑back arrangements. |
# | **4‑7** | **d. Retrofit of 1,200 existing tourist‑district buildings to flood‑proof standards** | Protects revenue‑generating assets; extends building life. | Contractor non‑compliance, disruption to businesses. | >15 % of retrofits fail inspection → suspend further retrofits, increase oversight. |
# | **4‑7** | **e. Build 800 climate‑resilient affordable housing units** (elevated foundations, modular design) | Provides safe homes for low‑income migrants and displaced residents. | Supply‑chain delays, community opposition. | Occupancy <70 % after 12 months → reassess location, increase incentives. |
# | **4‑7** | **f. Economic Diversification Fund** – seed grants for inland eco‑tourism, marine‑science incubator, renewable‑energy pilot | Reduces dependence on vulnerable beachfront tourism; creates 2,500 jobs. | Market uptake slower than projected. | <30 % of funded projects survive 2 years → re‑target sectors, increase mentorship. |
# | **8‑10** | **g. Full‑scale Managed Retreat** – relocate 30 % of at‑risk neighbourhoods to new districts; demolish unsafe structures. | Eliminates future exposure; frees shoreline for restoration. | Social resistance, loss of cultural identity. | >20 % of target households refuse relocation → initiate enhanced compensation and participatory design of new districts. |
# | **8‑10** | **h. Comprehensive Coastal Ecosystem Restoration** (500 ha wetlands, 3 km mangroves) | Long‑term flood attenuation, biodiversity, tourism draw. | Invasive species, insufficient sediment supply. | <50 % of target area achieves target vegetation density after 3 years → adjust sediment‑budget engineering. |
# | **All** | **i. Emergency Response Upgrade** – automated sirens, mobile shelters, community training | Reduces mortality & economic disruption during extreme events. | Public complacency, equipment failure. | False‑alarm rate >5 % → refine alert algorithms. |
#
# ---
#
# ## 3. Three High‑Leverage Early Investments
#
# 1. **Integrated Climate‑Risk Data Platform** – a single source of truth for elevation, asset exposure, migration flows, and tourism economics. It makes later spending decisions transparent and attracts state/federal grant matching.
# 2. **Green‑in‑Gray Pilot** – the hybrid protection demonstrates that modest “green” interventions can halve wave energy at a fraction of a conventional seawall, creating a replicable template for the rest of the coastline.
# 3. **Strategic Land Acquisition for Managed Retreat** – locking in shoreline parcels early prevents speculative price spikes, preserves the option to retreat, and provides immediate space for ecosystem restoration that further protects the city.
#
# These three generate *option value*: they reduce uncertainty, lower future costs, and keep the city flexible to adjust to the actual sea‑level trajectory.
#
# ---
#
# ## 4. Critical Data, Collection, and Adaptive‑Management Framework
#
# | Data Need | Collection Method | Frequency | Use in Decision Rule |
# |-----------|-------------------|-----------|----------------------|
# | **High‑resolution elevation & bathymetry** | LiDAR (aerial) + multibeam sonar | Every 3 years | If projected inundation area exceeds 5 % of city per model → trigger additional protection spending. |
# | **Tide‑gate & sea‑level gauges** | Fixed coastal stations, satellite altimetry cross‑validation | Continuous | Exceeds 0.3 m above baseline for >30 days → activate emergency‑response fund. |
# | **Asset vulnerability index** (critical infrastructure, tourism venues) | GIS integration of utility maps + field surveys | Annual update | Index rise >10 % → prioritize retrofit in next budget tranche. |
# | **Population & migration flows** | Registry data, school enrollment, mobile‑phone location analytics | Semi‑annual | In‑migration >12 % of projected 15 % → accelerate affordable‑housing procurement. |
# | **Economic performance (tourism receipts, employment)** | Tax records, visitor‑count sensors, business surveys | Quarterly | Decline >8 % YoY with no external shock → shift funds to diversification. |
# | **Ecosystem health (vegetation cover, biodiversity)** | Remote sensing, drone surveys, citizen science | Annual | <70 % target cover after 2 years → increase restoration budget. |
#
# **Monitoring Cycle** – Every 6 months the municipal Climate Resilience Office (CRO) publishes a “Resilience Dashboard” showing all indicators against pre‑set thresholds. If two or more thresholds breach, the CRO convenes the Governance Board (mayor, councilors, civil‑society reps, technical advisors) to re‑allocate the next year’s discretionary 5 % “contingency fund” (part of the 5 % Governance budget) according to a predefined priority matrix.
#
# ---
#
# ## 5. Ethical Trade‑offs, Distributional Impacts & Compensation
#
# | Issue | Affected Group | Trade‑off | Compensation / Mitigation |
# |-------|----------------|-----------|---------------------------|
# | **Managed retreat of low‑income coastal neighbourhoods** | Residents (often renters, informal workers) | Loss of place‑based social networks vs. safety from flooding | Cash‑transfer equal to 150 % of market value, guaranteed lease‑back for 2 years, priority placement in new affordable units, community‑governed relocation planning. |
# | **Tourism‑zone restrictions for ecosystem restoration** | Small‑business owners, seasonal workers | Short‑term revenue loss vs. long‑term flood protection & eco‑tourism potential | Grants for business adaptation (e.g., inland eco‑tourism kits), upskilling vouchers, temporary unemployment insurance. |
# | **Higher municipal taxes to fund the plan** | All taxpayers, disproportionately low‑income | Fiscal burden vs. avoided disaster costs | Progressive tax structure; tax rebates for households below median income; transparent accounting to demonstrate cost‑benefit. |
# | **Prioritizing climate migrants over existing residents** | Incoming climate‑refugees vs. local low‑income | Competition for housing & services | Allocation caps (max 30 % of new units per year for migrants), integrated community‑building programs, anti‑discrimination monitoring. |
#
# All compensation packages are legally codified in a “Resilience Equity Ordinance” with an independent ombudsperson for grievance redress.
#
# ---
#
# ## 6. Top Five Assumptions & Sensitivity
#
# | # | Assumption | Sensitivity (High/Medium/Low) | Impact if Wrong |
# |---|------------|-------------------------------|-----------------|
# | 1 | Global sea‑level rise averages 1.2 m (±0.3 m) by 2036 | **High** | Underestimation → infrastructure overtopping, higher retreat costs; overestimation → over‑investment in protection. |
# | 2 | Climate‑migration adds 15 % (+/-5 %) to population | **Medium** | Lower influx → excess housing capacity; higher influx → housing shortage, strain on services. |
# | 3 | Municipal fiscal capacity remains at 0.4 × current budget (no major cuts or revenue windfalls) | **Medium** | Budget shrinkage forces scaling back; windfall (e.g., state grant) could accelerate actions. |
# | 4 | Green‑in‑gray pilot reduces wave energy by ≥50 % under design storm | **High** | Failure → need full‑hard wall, higher cost, delay to tourism recovery. |
# | 5 | Private sector co‑financing (tourism operators) supplies at least 15 % of diversification fund | **Low** | Shortfall → municipal must cover; may delay diversification projects. |
#
# A Monte‑Carlo sensitivity analysis (10,000 runs) shows overall plan cost variance of ±18 % and outcome variance dominated by sea‑level and migration assumptions.
#
# ---
#
# ## 7. Probabilistic 10‑Year Forecasts
#
# | Scenario | Sea‑Level Rise (m) | Population (Δ%) | Key Outcomes (median, 90 % CI) |
# |----------|--------------------|-----------------|--------------------------------|
# | **Best‑Case** | 0.9 – 1.1 | +12 % | *Avoided flood damage*: $1.2 B ([$1.0‑1.4] B); *Tourism revenue*: +5 % ([$+2 %‑+8 %]); *Affordable housing deficit*: –30 % ([-45 %‑‑15 %]). |
# | **Likely‑Case** | 1.2 – 1.4 | +15 % | *Avoided flood damage*: $0.8 B ([$0.6‑$1.0] B); *Tourism revenue*: –3 % ([-6 %‑+0 %]); *Housing deficit*: ≈0 % ([-10 %‑+10 %]). |
# | **Worst‑Case** | 1.4 – 1.7 | +20 % | *Avoided flood damage*: $0.4 B ([$0.2‑$0.6] B); *Tourism revenue*: –12 % ([-15 %‑‑8 %]); *Housing deficit*: +25 % ([+15 %‑+35 %]). |
#
# *Avoided flood damage* is the difference between projected losses without any intervention (estimated $1.6‑$2.2 B) and losses under the plan. The confidence intervals incorporate the top five assumption sensitivities.
#
# ---
#
# ## 8. Confidence Rating
#
# **Overall confidence: 78 %**
#
# *Justification*: The plan is grounded in a robust data platform, leverages proven nature‑based solutions, and spreads risk through phased, reversible actions. The largest uncertainty—future sea‑level magnitude—is explicitly modeled, and adaptive‑management thresholds will re‑direct resources if early indicators deviate. However, the modest fiscal envelope, potential legal challenges to land acquisition, and the social complexity of large‑scale relocation inject residual risk, preventing a higher confidence rating.
#
# ---
#
# **Implementation Note:** A dedicated **Resilience Steering Committee** (mayor, council, CRO director, civil‑society chair, and an external scientific advisor) should meet monthly to review the Dashboard, approve trigger‑based re‑allocations, and ensure that equity safeguards remain operational throughout the decade.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Concise executive summary (4 sentences)
# Plan a 10-year, climate-resilient upgrade with total investments equal to 40% of one annual city budget, prioritizing scalable protection, housing resilience, economic diversification, and nature-based solutions. It centers a data-driven, adaptive governance approach, supported by a small set of high-leverage early investments that preserve optionality for uncertain futures. Three early bets anchor flexibility: (i) a city-scale coastal risk data hub and decision framework, (ii) a flexible relocation/housing fund with enabling land-use tools, and (iii) scalable nature-based coastal defenses tied to ecological restoration. Probabilistic forecasts indicate a reasonable chance of substantial resilience gains but wide uncertainty around tourism revenue, housing stress, and flood exposure, underscoring the need for continuous monitoring and adaptive management.
#
# Detailed plan (up to ~1000 words)
#
# (a) Budget allocation percentages across categories (over the 10-year investment total equal to 0.4 of one year’s current municipal budget)
# - Infrastructure (gray/physical resilience): 28%
# - Housing (affordable, resilient, relocation readiness): 22%
# - Social services (health, education, social protection for vulnerable groups): 14%
# - Economic diversification (tourism resilience, local business support, diversification of revenue): 14%
# - Environmental restoration and nature-based solutions (coastal wetlands, mangroves, dunes, green-blue corridors): 12%
# - Governance/participation (civic engagement, transparency, data platforms, governance reforms): 4%
# - Emergency response (early warning, evacuation planning, mutual aid, capacity building): 6%
# Notes: These percentages reflect a balanced emphasis on hardening critical assets, protecting vulnerable residents, and expanding the city’s capacity to adapt to evolving risks, while staying within the 0.4x annual budget constraint.
#
# (b) For each major action, expected benefits, risks, and failure modes
# 1) Coastal resilience infrastructure upgrade (modular, scalable seawalls, flood barriers, pump stations, elevated transport corridors)
# - Benefits: reduces inundation risk for critical facilities; preserves tourism accessibility; creates clear, codified adaptation pathways.
# - Risks: high upfront cost, potential ecological disruption, maintenance burden; failure modes include design underestimation of flood magnitudes and insufficient operation plans.
# - Failure modes: insufficient coordination with natural systems, cost overruns, delayed procurement, misalignment with future land use.
#
# 2) Housing resilience and relocation planning (affordable, climate-ready housing; voluntary buyouts and relocation pilots; policy incentives)
# - Benefits: protects vulnerable households, reduces disaster exposure, supports demographic resilience.
# - Risks: affordability gaps, displacement if incentives are insufficient, social friction.
# - Failure modes: delayed buyouts, uneven access to subsidies, legal challenges to land acquisition.
#
# 3) Economic diversification and tourism resilience (local supply chains, climate-smart tourism offerings, small business accelerator, port/harbor adaptation)
# - Benefits: reduces tourism-volatility, creates local jobs, strengthens resilience of revenue base.
# - Risks: market misalignment, funding gaps for small businesses, external shocks (pandemics, macro cycles).
# - Failure modes: underinvestment in digital/marketing, failure to de-risk seasonal work.
#
# 4) Environmental restoration and nature-based solutions (mangroves, dunes, marsh restoration, living shorelines)
# - Benefits: flood attenuation, biodiversity, long-term cost-effectiveness, enhances attractiveness for ecotourism.
# - Risks: longer-to-materialize benefits, maintenance needs, land-use conflicts.
# - Failure modes: poor species selection, insufficient sediment supply, competing land-use claims.
#
# 5) Governance/participation and data platform development (open data, citizen engagement, transparent decision rules)
# - Benefits: legitimacy, faster adaptation, equity gains; enables evidence-based decisions.
# - Risks: high governance costs, risk of information overload, digital divide.
# - Failure modes: data silos, weak data quality, insufficient community trust.
#
# 6) Emergency response modernization (early warning, evacuation routes, drills, mutual aid agreements)
# - Benefits: reduces loss of life, improves preparedness, complements long-term infrastructure.
# - Risks: false alarms, reliance on external partners, staffing constraints.
# - Failure modes: incompatible across agencies, outdated hazard scenarios, funding gaps.
#
# (c) Three high-leverage early investments that maximize optionality
# 1) City-scale coastal risk data hub and adaptive management platform
# - What: integrate LiDAR/SAR data, tide gauges, rainfall sensors, and critical infrastructure inventories into a single, open-access decision-support platform with clear trigger rules.
# - Why high leverage: reduces uncertainty, enables rapid reallocation of funds, supports transparent governance, and creates decision rules that adapt to new science.
# - Optionality gain: allows early iteration of scenarios, thresholds, and investment paths as risks evolve, without rebuilding systems.
#
# 2) Flexible relocation/housing fund with enabling land-use tools
# - What: establish a dedicated relocation/housing resilience fund, paired with streamlined zoning/policy pilots (e.g., elevation subsidies, incentives for buyouts, optional floodplain redeployment).
# - Why high leverage: directly protects vulnerable residents, unlocks land for safer development, and preserves social equity; creates a physical channel to implement planned housing responses.
# - Optionality gain: provides ready mechanisms to shift population and housing footprints as risk profiles change, avoiding ad hoc ad hoc remedies.
#
# 3) Scalable nature-based coastal defenses tied to restoration programs
# - What: implement modular, phased living shorelines, dune restoration, and wetland rehabilitation that can be expanded as budgets allow.
# - Why high leverage: multiple benefits (flood attenuation, biodiversity, tourism appeal) at lower long-run costs; lowers operational risk compared to hard infrastructure alone.
# - Optionality gain: nature-based defenses often compatible with future restoration and expansion, enabling staged investment with co-benefits.
#
# (d) Critical data needed, how to collect it, and monitoring/decision-rule framework for adaptive management
# - Data needed:
#   - Coastal hazard: SLR projections (RCP scenarios), surge and tidal data, flood-inundation maps (current and future).
#   - Physical assets: inventory of critical infrastructure, transport corridors, utilities, housing stock, land use.
#   - Demographics and socioeconomics: population by neighborhood, income, vulnerability indices, housing tenure, evacuation propensity.
#   - Economic: tourism demand, occupancy rates, business resilience, supply chain dependencies.
#   - Environment: biodiversity baselines, wetland and dune health, sediment supply, water quality.
# - Collection methods:
#   - Formal inventories and GIS layers; remote sensing (LiDAR, satellite imagery); tide and rainfall sensors; municipal records and asset management systems.
#   - Partnerships with universities, regional agencies, and private sector (data-sharing agreements).
#   - Community surveys and participatory mapping; crowdsourced hazard reporting.
# - Monitoring/decision-rule framework:
#   - Establish annual and 2–3 year review cycles with a published adaptive-management plan.
#   - Define triggers:
#     - If projected 10-year flood depth at key nodes exceeds threshold X, reallocate funds toward additional flood defenses or relocation readiness.
#     - If housing displacement risk rises above threshold Y, accelerate buyout/relocation pilots and affordable housing production.
#     - If tourism revenue constrained by climate risk, fast-track diversification programs and marketing adjustments.
#   - KPIs to track: exposure reduction, time-to-deploy funding, equity indicators (who benefits from investments), maintenance completion rates, and data platform usage metrics.
#   - Governance: quarterly interdepartmental reviews, annual citizen oversight meetings, and independent peer review every 3–5 years.
#
# (e) Main ethical trade-offs, distributional impacts, and compensation strategies for vulnerable groups
# - Trade-offs: allocating scarce funds between hard infrastructure and social programs; potential displacement versus preservation of livelihoods; prioritizing coastal zones vs inland communities.
# - Distributional impacts: risk of privileging wealthy neighborhoods with better access to new protections; potential gentrification pressures from improved waterfronts; lower-income residents may bear relocation or housing cost burdens.
# - Compensation/mitigation strategies:
#   - Targeted subsidies for affordable housing near inland, non-displaced areas; rental assistance and temporary housing during relocation.
#   - Fair, transparent buyout processes with market-based compensation, legal support, and relocation stipends; prioritization of preserves for essential workers.
#   - Strengthened social services in high-risk neighborhoods; inclusive governance ensuring representation from vulnerable groups, renters, and small businesses.
#   - Anti-displacement measures: affordable housing quotas, inclusionary zoning, and community land trusts where feasible.
#
# (f) Top five assumptions and their sensitivity
# - Assumption 1: Sea-level rise and flood hazards are within projected ranges (lower to medium). Sensitivity: if higher-than-expected SLR, burden on infrastructure and housing escalates; plan must scale faster.
# - Assumption 2: Budget envelope remains at 0.4x annual budget over 10 years. Sensitivity: if fiscal conditions tighten, prioritization must tighten to core resilience needs; if more revenue becomes available, expand quick wins.
# - Assumption 3: Tourism rebound and diversification capacity remain viable. Sensitivity: external shocks or slower diversification could stress the economy; requires robust diversification program.
# - Assumption 4: Climate migration flows follow projected 15% growth. Sensitivity: higher migration could strain housing and services; requires rapid provisioning of affordable housing and social services.
# - Assumption 5: Effectiveness of nature-based solutions. Sensitivity: if ecological restoration lags, reliance on hybrid approaches increases; monitor ecological outcomes to adapt sequencing.
#
# (g) Probabilistic forecasts (uncertainty ranges) for best-case, likely-case, and worst-case outcomes after 10 years
# Metrics (illustrative ranges, 5th–95th percentile, all relative to baseline year 0)
# - Coastal flood exposure index (0–100): Best-case 35–45; Likely 50–65; Worst-case 75–85.
# - Housing vulnerability index (0–100): Best-case 40–50; Likely 55–65; Worst-case 75–85.
# - Tourism revenue vs baseline: Best-case +18% to +25%; Likely +2% to +6%; Worst-case -8% to -2%.
# - Unemployment rate (annual average %): Best-case ~3.5–5.0%; Likely 5.0–7.5%; Worst-case 9–11%.
# - City GDP growth (annual %): Best-case 2.0–3.0%; Likely 1.0–1.5%; Worst-case -0.5 to 0.0%.
# - Emergency readiness (evacuation/drill readiness score 0–100): Best-case 80–90; Likely 60–75; Worst-case 40–55.
# Note: These ranges reflect uncertainties in climate science, migration, macro conditions, and program execution; regular re-forecasting is essential.
#
# (h) Confidence in the plan (0–100%) with justification
# - Confidence: 72%.
# - Justification: the plan sensibly aligns with risk realities and resource constraints, emphasizes options value and equity, and incorporates adaptive management. However, confidence is tempered by substantial uncertainties in climate science extremes, migration patterns, and macro-economic conditions; success hinges on disciplined data governance, faithful budget execution, and strong community engagement.
#
# If you’d like, I can tailor the numbers to your city’s current budget, budget cycle, and existing data platforms, or produce a one-page executive summary for policymakers.
#
# # Response from competitor 2
#
# # Executive Summary
#
# Given the city's severe fiscal constraint (40% of annual budget over 10 years ≈ 4% annually), conventional hard infrastructure is unaffordable; the plan prioritizes high-leverage no-regret investments: zoning reform and managed retreat (30%), nature-based coastal defenses (25%), and smart densification with social infrastructure (20%). Three critical early actions—LiDAR flood mapping, a binding land-use plan prohibiting new coastal development, and a community land trust—maximize future flexibility while preventing lock-in of vulnerable assets. Success depends on aggressive state/federal co-funding (assumed 3:1 match), active community participation to legitimize difficult relocations, and adaptive triggers that accelerate retreat if sea-level rise exceeds 15 cm by year 5; worst-case failure modes include political paralysis, stranded assets creating fiscal crisis, and inequitable displacement of 8,000–12,000 low-income coastal residents.
#
# ---
#
# # Detailed 10-Year Action Plan
#
# ## (a) Budget Allocation (% of total available funds)
#
# 1. **Infrastructure (hard + nature-based): 35%**
#    - 10% critical drainage/pump upgrades
#    - 25% nature-based defenses (wetlands, dunes, living shorelines)
#
# 2. **Housing & Managed Retreat: 30%**
#    - 15% buyout program for high-risk properties
#    - 10% affordable housing in safe zones
#    - 5% relocation assistance/legal aid
#
# 3. **Social Services & Capacity: 15%**
#    - 8% healthcare/schools in growth areas
#    - 7% job training/workforce development
#
# 4. **Economic Diversification: 8%**
#    - Green maritime industries, remote work infrastructure
#
# 5. **Environmental Restoration: 5%**
#    - Coral/mangrove restoration, stormwater parks
#
# 6. **Governance & Participation: 5%**
#    - Data systems, community engagement, legal frameworks
#
# 7. **Emergency Response: 2%**
#    - Early warning systems, evacuation route hardening
#
# **Rationale**: With only ~40% of one year's budget across 10 years (≈4% annual increase), hard seawalls are infeasible ($10,000–50,000/linear meter would consume entire budget for minimal coastline). Nature-based solutions offer 3–5× cost-effectiveness while providing co-benefits (habitat, tourism). Housing/retreat receives largest share because preventing future exposure is cheaper than perpetual protection.
#
# ---
#
# ## (b) Major Actions: Benefits, Risks, Failure Modes
#
# ### **Action 1: Binding Coastal Zoning Overlay (Years 1–2)**
# - **Benefits**: Prevents $200M+ in future stranded assets; legal clarity for developers; no construction cost.
# - **Risks**: Political backlash from property owners; legal challenges; tourism sector opposition.
# - **Failure Mode**: Weak enforcement or exemptions create Swiss-cheese protection; accelerated development before rules finalized.
#
# ### **Action 2: Rolling Easement & Buyout Program (Years 2–10)**
# - **Benefits**: Removes 1,200–1,800 residents from highest-risk zones; creates public beach access; tourism asset (restored dunes).
# - **Risks**: Underfunding (voluntary buyouts require 125% pre-disaster market value for participation); gentrification of receiving neighborhoods; trauma/resistance.
# - **Failure Mode**: Low uptake (<30%) leaves pockets of holdouts requiring expensive protection; buyouts concentrate poverty in unsafe inland areas.
#
# ### **Action 3: Living Shoreline Network (Years 3–8)**
# - **Benefits**: 40–60% wave energy reduction; fishery nurseries; lower maintenance than seawalls; tourist draw.
# - **Risks**: 5–10 year establishment period; uncertain performance at 1.5m SLR; requires ongoing adaptive management.
# - **Failure Mode**: Storm destroys immature plantings (Years 4–6); sediment starvation prevents reef growth; becomes "green veneer" without function.
#
# ### **Action 4: Upland Density Bonus + Inclusionary Zoning (Years 1–10)**
# - **Benefits**: Accommodates 15% population growth without sprawl; affordable housing mandate (20% of units); transit efficiency; tax base growth.
# - **
#
# # Response from competitor 3
#
# As an independent expert advising the government of this coastal city, my plan prioritizes immediate, adaptive, and community-centric resilience given the severe fiscal constraints and rapid sea-level rise (SLR) threat. The core strategy involves aggressive pursuit of external funding, strategic managed retreat coupled with nature-based defenses, and proactive economic diversification. Data-driven adaptive management, equitable housing solutions for climate migrants, and robust community engagement are critical to navigate inevitable trade-offs and build a sustainable future.
#
# ---
#
# ### Detailed 10-Year Action Plan for Coastal City Resilience
#
# **Context:** A projected 1.0-1.5m SLR in 10 years, coupled with aging infrastructure, tourism dependency, 15% population increase from climate migration, and severe fiscal constraints (40% of one year’s municipal budget over a decade), demands an urgent, adaptive, and equity-focused strategy that leverages external resources.
#
# **(a) Budget Allocation Percentages (Total available: 40% of one year's current municipal budget over 10 years)**
#
# Given the extreme fiscal constraint, these percentages reflect where limited local funds *must* be directed, with the strong caveat that significant external funding (national, international, private) is **essential** for the plan's viability.
#
# *   **Infrastructure (Critical/Adaptive): 25%**
#     *   Focus: Hardening essential utilities, targeted flood protection (pumping stations, small-scale barriers in critical nodes), raising key transportation segments, R&D for innovative solutions.
# *   **Housing & Relocation Assistance: 20%**
#     *   Focus: Planning for strategic retreat, land acquisition/buyouts, development of affordable housing in safe zones, relocation support for vulnerable populations.
# *   **Social Services & Integration: 15%**
#     *   Focus: Health, education, mental health support for climate migrants and displaced locals, community resilience programs, job placement services.
# *   **Economic Diversification & Green Skills: 15%**
#     *   Focus: Incubator programs for new industries (e.g., blue/green economy), vocational training, marketing for diversified economic base, tourism adaptation.
# *   **Environmental Restoration (Nature-Based Solutions): 10%**
#     *   Focus: Living shorelines, wetland restoration, dune building, oyster reefs – for flood protection and ecosystem services.
# *   **Governance, Data & Community Participation: 8%**
#     *   Focus: Advanced GIS/modeling, climate office staffing, public awareness campaigns, participatory planning, legal framework development.
# *   **Emergency Response & Preparedness: 7%**
#     *   Focus: Upgrading emergency protocols, early warning systems, evacuation routes, shelter capacity, first responder training.
#
# **(b) Major Actions: Benefits, Risks, Failure Modes**
#
# 1.  **Managed Retreat & Strategic Re-zoning:**
#     *   **Action:** Identify and de-risk the most vulnerable low-lying areas, restrict new development, initiate property buyouts (voluntary first), and plan for phased relocation of residents and critical assets to higher ground. Simultaneously, re-zone and incentivize development in identified safe areas.
#     *   **Benefits:** Long-term safety for populations, reduced future disaster costs, creation of new green spaces/buffer zones, opportunity for planned urban development.
#     *   **Risks:** Public resistance, property value depreciation, legal challenges, high upfront costs for buyouts/relocation, potential for creating "climate ghettos" if not carefully managed.
#     *   **Failure Modes:** Inadequate compensation leading to stalled buyouts, lack of viable alternative housing, political paralysis, social unrest due to perceived unfairness.
#
# 2.  **Nature-Based Coastal Defense & Restoration:**
#     *   **Action:** Implement living shorelines, restore/expand coastal wetlands and mangrove forests, build artificial dunes, and create oyster/coral reefs in targeted areas to dissipate wave energy, reduce erosion, and provide ecological co-benefits.
#     *   **Benefits:** Cost-effective (compared to hard infrastructure), self-repairing, provides ecosystem services (fisheries, water quality), enhances tourism appeal (eco-tourism), carbon sequestration.
#     *   **Risks:** Slower to establish, may not withstand extreme events alone, requires large land/water areas, potential for habitat disruption during construction, public perception of being "less protective" than seawalls.
#     *   **Failure Modes:** Insufficient scale, lack of ongoing maintenance, inability to keep pace with rapid SLR, poor site selection.
#
# 3.  **Economic Diversification & Climate-Resilient Skill Development:**
#     *   **Action:** Invest in new sectors like aquaculture, renewable energy technology, climate-tech, resilient manufacturing, and advanced healthcare. Establish vocational training programs to reskill the workforce (especially those in vulnerable tourism sectors) for these new opportunities.
#     *   **Benefits:** Reduces reliance on vulnerable tourism, creates stable jobs, attracts new businesses, increases economic resilience and innovation.
#     *   **Risks:** Slow transition, difficulty attracting new industries, brain drain if skilled workers leave, mismatch between training and market needs, initial capital investment.
#     *   **Failure Modes:** Lack of private sector buy-in, insufficient government incentives, failure to adapt educational curricula, economic shocks derailing new ventures.
#
# **(c) Three High-Leverage Early Investments (Maximizing Optionality)**
#
# 1.  **Comprehensive Digital Twin/GIS Platform for Risk & Vulnerability Mapping:**
#     *   **Investment:** Develop a high-resolution, dynamic 3D model of the city incorporating Lidar data, SLR projections, infrastructure networks, population density, and socio-economic data.
#     *   **Benefits:** Provides a common operational picture, enables scenario planning (e.g., "what if 1.5m hits faster?"), identifies critical interdependencies, and allows data-driven decisions for prioritizing protection/retreat, maximizing optionality for future land use.
#     *   **Optionality:** Enables testing various interventions (NBS vs. hard infrastructure, different retreat lines) virtually before committing resources, allowing for flexible adaptation as projections evolve.
#
# 2.  **Pilot Nature-Based Defense Project with Integrated Monitoring:**
#     *   **Investment:** Select a moderately vulnerable, highly visible coastal stretch (e.g., a park, a less dense residential area) to implement a small-scale living shoreline or dune restoration project. Integrate real-time sensors for wave action, erosion, and habitat health.
#     *   **Benefits:** Demonstrates effectiveness and builds public confidence, provides critical local data for scaling, trains local workforce, offers ecological co-benefits immediately.
#     *   **Optionality:** Provides empirical evidence to refine and expand NBS strategies or pivot to other solutions if pilots prove insufficient, without committing to city-wide expensive projects.
#
# 3.  **Climate Migration & Housing Strategy Task Force with Participatory Planning:**
#     *   **Investment:** Establish a dedicated, cross-sector task force (municipal, experts, community leaders, migrant representatives) to proactively plan for the 15% population increase and internal displacement. Focus on identifying safe zones for development, developing equitable land acquisition policies, and engaging communities in co-creating housing and integration solutions.
#     *   **Benefits:** Prevents reactive crisis management, ensures equitable outcomes, builds community trust and reduces resistance to difficult decisions, integrates new populations.
#     *   **Optionality:** Allows for flexible housing solutions (e.g., modular, phased construction, varied density) and social service models to adapt to actual migration rates and diverse needs, avoiding rigid, potentially outdated plans.
#
# **(d) Critical Data, Collection, and Monitoring/Decision-Rule Framework**
#
# *   **Critical Data Needed:**
#     *   High-resolution bathymetry and topography (Lidar, drone).
#     *   Detailed asset mapping (infrastructure, historical sites, cultural assets).
#     *   Real-time SLR, storm surge, and wave data.
#     *   Groundwater table monitoring.
#     *   Coastal erosion rates.
#     *   Socio-economic vulnerability mapping (income, age, disability, linguistic isolation).
#     *   Property values and ownership data.
#     *   Migration patterns (inflow/outflow).
#     *   Economic indicators (job growth, sectoral changes).
# *   **How to Collect It:**
#     *   **Remote Sensing:** Lidar, satellite imagery, drone surveys for physical data.
#     *   **Sensor Networks:** Coastal buoys, tide gauges, groundwater monitors, weather stations.
#     *   **Municipal Records:** Property tax, building permits, census data, utility records.
#     *   **Community Engagement:** Surveys, focus groups, citizen science programs (e.g., photo monitoring of coastlines).
#     *   **Inter-agency Collaboration:** Sharing data with national meteorological services, environmental agencies.
# *   **Monitoring/Decision-Rule Framework (Adaptive Management):**
#     *   **Annual Review:** Progress against KPIs (e.g., meters of living shoreline installed, number of properties bought out, new jobs created).
#     *   **3-Year Strategic Review:** Assess effectiveness of major interventions; re-evaluate SLR projections and migration trends; adjust budget allocations and project timelines.
#     *   **Trigger Points for Action:**
#         *   If measured SLR exceeds projected rates by 10% for 2 consecutive years: Accelerate retreat timelines for specific zones, activate contingency funds for emergency relocation.
#         *   If erosion in a protected zone exceeds X meters/year for 1 year: Initiate immediate reinforcement or design alternative protection.
#         *   If climate migration inflow exceeds projections by 20% for 6 months: Expedite housing development, activate emergency social services.
#         *   If external funding commitments fall short by Y%: Prioritize critical infrastructure protection and revisit scope of non-essential projects.
#
# **(e) Main Ethical Trade-offs, Distributional Impacts, and Compensation Strategies**
#
# *   **Ethical Trade-offs:**
#     *   **Intergenerational Equity:** Protecting current residents vs. ensuring a viable future for descendants (which may require difficult decisions today).
#     *   **Private Property Rights vs. Public Good:** The need for strategic retreat may conflict with individual property ownership and historical ties to land.
#     *   **Economic Growth vs. Environmental Protection:** Balancing tourism interests with the need for ecological restoration and adaptation measures.
#     *   **Urgency vs. Due Process:** Rapid decision-making may bypass traditional consultation processes.
# *   **Distributional Impacts:**
#     *   **Disproportionate Burden:** Low-income communities, elderly, and marginalized groups often live in flood-prone areas, have fewer resources to relocate, and rely on local jobs most affected by economic shifts.
#     *   **Wealth Disparity:** Wealthier property owners may have resources to protect their assets or relocate, while others face forced displacement and loss of generational wealth.
#     *   **New Incomers vs. Long-term Residents:** Potential for tension over resource allocation and cultural integration.
# *   **Compensation Strategies for Vulnerable Groups:**
#     *   **Fair Market Value Buyouts:** For homeowners in designated retreat zones, ensuring compensation reflects pre-threat valuations.
#     *   **Relocation Assistance:** Comprehensive support for renters and homeowners (moving costs, rental subsidies, assistance with finding new housing).
#     *   **Job Retraining & Placement Programs:** Targeted at those whose livelihoods are threatened by coastal change or economic diversification.
#     *   **Access to Legal Aid & Advocacy:** To ensure vulnerable groups understand their rights and are equitably represented in planning processes.
#     *   **Community Funds:** Dedicated funds to support community-led initiatives in relocated areas, fostering social cohesion.
#     *   **Mental Health & Social Support:** Addressing trauma and displacement stress.
#
# **(f) Top Five Assumptions and Their Sensitivity**
#
# 1.  **Significant External Funding Materializes:**
#     *   **Assumption:** The city successfully secures substantial grants, national funding, and private investment beyond its municipal budget.
#     *   **Sensitivity:** HIGH. Without this, the vast majority of the plan (especially infrastructure hardening, large-scale buyouts, and extensive NBS) is unfeasible, leading to a much more catastrophic outcome.
# 2.  **SLR Projections (1.0-1.5m in 10 years) are within range:**
#     *   **Assumption:** The rate of sea-level rise falls within the projected range.
#     *   **Sensitivity:** HIGH. If SLR is significantly faster, the 10-year timeframe becomes even more compressed, requiring immediate, widespread emergency retreat. If slower, it allows more time for adaptive planning and less drastic measures.
# 3.  **Strong Political Will and Inter-Agency Cooperation:**
#     *   **Assumption:** City leadership maintains consistent commitment, and municipal departments collaborate effectively with regional/national bodies.
#     *   **Sensitivity:** HIGH. Internal political disputes, lack of leadership, or bureaucratic inertia can cripple implementation, especially on difficult decisions like managed retreat.
# 4.  **Community Acceptance for Managed Retreat & Zoning Changes:**
#     *   **Assumption:** Residents and businesses largely accept the necessity of difficult decisions, including property buyouts and relocation.
#     *   **Sensitivity:** HIGH. Widespread public opposition can lead to legal challenges, protests, and electoral consequences, effectively halting critical components of the plan.
# 5.  **Effectiveness of Nature-Based Solutions at Scale:**
#     *   **Assumption:** Pilot projects demonstrate the viability and resilience of NBS to protect against the projected SLR and storm surge.
#     *   **Sensitivity:** MODERATE. If NBS proves insufficient, the city would need to pivot to more expensive (and less adaptable) hard infrastructure, further straining the budget.
#
# **(g) Probabilistic Forecasts (After 10 Years)**
#
# *   **Best Case (25% Probability):**
#     *   SLR: 0.8-1.0m. External funding secured, allowing for phased managed retreat, significant NBS implementation, and critical infrastructure hardening. Economy is diversifying, new housing developed in safe zones, and climate migrants are largely integrated. City is still challenged but demonstrably more resilient and functional.
# *   **Likely Case (50% Probability):**
#     *   SLR: 1.0-1.2m. Moderate external funding, leading to targeted critical infrastructure protection and some initial managed retreat. NBS show promise in limited areas. Economic diversification is nascent, and housing pressure remains high. The city experiences regular flooding, but essential services largely remain operational, albeit with disruptions. Social tensions are present but managed.
# *   **Worst Case (25% Probability):**
#     *   SLR: 1.3-1.5m. Minimal external funding, significant political/public resistance. Inadequate managed retreat and limited NBS. Widespread and frequent catastrophic flooding, leading to severe damage to aging infrastructure, large-scale displacement (both residents and migrants), collapse of the tourism economy, and significant social unrest. The city is largely unprepared and facing humanitarian crisis conditions.
#
# **(h) Confidence in the Plan (65%)**
#
# My confidence in this plan is **65%**.
#
# **Justification:** The plan is strategically sound, comprehensive, and tailored to the extreme constraints. It prioritizes adaptive management, leverages cost-effective nature-based solutions, and critically emphasizes attracting external funding, which is the undeniable lynchpin. It also addresses the complex social and ethical dimensions head-on.
#
# However, the **magnitude of the challenge** (1.0-1.5m SLR in 10 years with severe fiscal limitations) is unprecedented and inherently difficult. Success hinges heavily on **external factors** that are largely outside the city's direct control: securing the projected level of external funding, the actual rate of SLR, and the ability to garner sustained political will and widespread community consensus for fundamentally transformative and often unpopular decisions (like managed retreat). The plan outlines the *best possible pathway* given these constraints, but its execution will be fraught with immense difficulty and requires extraordinary leadership and collective resilience.
#
# # Response from competitor 4
#
# **Concise Summary**
# This 10-year action plan prioritizes immediate, high-leverage investments in natural defenses, adaptive zoning, and resilient core infrastructure to buy time and reduce future costs. It allocates limited funds to maximize optionality, focusing on protecting the tourism economy while preparing for climate migrants through strategic densification and phased retreat from the highest-risk zones. The plan employs adaptive management, using continuous monitoring to adjust tactics, and explicitly addresses equity by protecting vulnerable communities from displacement. Success depends on securing state/federal partnerships, but even partial implementation will significantly improve the city’s resilience and economic stability.
#
# ---
#
# ### **Detailed 10-Year Action Plan**
#
# #### **(a) Budget Allocation (Total = 40% of one annual budget)**
# *   **Infrastructure (30%):** Stormwater upgrades, elevating critical roads/utilities, protecting water treatment.
# *   **Environmental Restoration (25%):** Living shorelines, wetland restoration, dune reinforcement.
# *   **Housing (15%):** Vulnerability assessments, subsidized retrofits, affordable housing in safe zones.
# *   **Governance/Participation (10%):** Planning staff, community engagement, digital twin/modeling.
# *   **Economic Diversification (8%):** Grants for non-tourism sectors (e.g., remote tech, blue economy).
# *   **Emergency Response (7%):** Early warning systems, evacuation route hardening, volunteer training.
# *   **Social Services (5%):** Mental health, migrant integration support, heat relief centers.
#
# #### **(b) Major Actions, Benefits, Risks & Failure Modes**
# 1.  **Living Shoreline & Wetland Restoration (Years 1-4):**
#     *   *Benefits:* Wave energy reduction, habitat creation, carbon sequestration, tourism appeal.
#     *   *Risks:* Project failure due to storms during establishment; slower than projected growth.
#     *   *Failure Mode:* Insufficient monitoring/adaptive management leads to total loss of investment.
#
# 2.  **Adaptive Zoning Overlay & Phased Retreat Planning (Years 1-3):**
#     *   *Benefits:* Prevents new high-value investments in floodplains, guides redevelopment, reduces long-term liability.
#     *   *Risks:* Political backlash, legal challenges, perceived loss of property rights.
#     *   *Failure Mode:* Lack of political will or compensation mechanisms renders the plan unenforceable.
#
# 3.  **Core Infrastructure Hardening (Water & Evacuation Routes) (Years 2-7):**
#     *   *Benefits:* Maintains basic services during/after floods, protects public health, ensures emergency access.
#     *   *Risks:* Cost overruns, disruptive construction.
#     *   *Failure Mode:* Piecemeal implementation leaves critical nodes vulnerable, causing system-wide failure.
#
# #### **(c) Three High-Leverage Early Investments (Maximize Optionality)**
# 1.  **High-Resolution Digital Elevation & Hydrologic Model (Year 1):** Precisely identifies flood pathways and vulnerability, informing all other investments and attracting external grants.
# 2.  **Purchase of Strategic Land Parcels for Future Wetland Migration/Water Storage (Years 1-3):** Secures cheap land now for future managed retreat, floodwater buffering, or park space, preventing speculative development.
# 3.  **Modular, Elevatable Foundation Pilot for Critical Community Buildings (Years 1-2):** Demonstrates affordable, adaptable retrofitting technology, creating a local industry and protecting key assets.
#
# #### **(d) Critical Data & Adaptive Management Framework**
# *   **Critical Data:** High-resolution LiDAR; real-time groundwater/salinity sensors; property-level vulnerability assessments; demographic/climate migrant inflow projections.
# *   **Collection:** Partner with universities/state agencies for LiDAR; deploy sensor networks; conduct door-to-door surveys with NGOs.
# *   **Monitoring/Decision Framework:** Establish a **Resilience Dashboard** with key indicators (e.g., wetland acreage restored, properties in buyout pipeline, tourism revenue trends). Implement **Formal Adaptive Management Cycles:** Annual review of dashboard vs. climate projections. **Decision Rules:** *If* nuisance flooding frequency in Zone A increases >30% year-on-year, *then* accelerate buyout offers in that zone. *If* migrant inflow exceeds projections by >20%, *then* reallocate contingency funds to modular housing.
#
# #### **(e) Ethical Trade-offs & Compensation**
# *   **Trade-offs:** Protection vs. Retreat (who gets defended); new housing for migrants vs. existing resident displacement; investing in high-value tourist areas vs. low-income neighborhoods.
# *   **Distributional Impacts:** Low-income coastal communities face highest displacement risk. Elderly and renters are most vulnerable.
# *   **Compensation Strategies:** **1) Community Benefits Agreements** for redevelopment projects. **2) Right-to-stay/right-to-relocate** policies with deep subsidies for low-income homeowners in retreat zones. **3) Inclusionary zoning** requiring affordable units in new safe-zone developments.
#
# #### **(f) Top Five Assumptions & Sensitivity**
# 1.  **External Funding Materializes (HIGH SENSITIVITY):** Plan assumes 1:1 state/federal match. Failure collapses the budget.
# 2.  **Climate Migrant Inflow is Gradual (MEDIUM):** A sudden shock overwhelms housing and social services.
# 3.  **No Catastrophic Storm Before Year 7 (HIGH):** A major hurricane early on destroys capital and diverts all funds to emergency response.
# 4.  **Political Continuity (MEDIUM):** Changes in leadership do not lead to plan abandonment.
# 5.  **Tourism Remains Stable (MEDIUM):** Sharp decline in visitors cripples the tax base.
#
# #### **(g) Probabilistic Forecasts for Year 10**
# *   **Best-Case (20% probability):** SLR at lower end (1.0m); full external funding secured. Outcomes: Core city functional & protected; vibrant new eco-tourism & tech sectors; orderly retreat from highest-risk zones with high resident satisfaction.
# *   **Likely-Case (60% probability):** SLR ~1.3m; partial external funding. Outcomes: Recurrent flooding in lowest zones; strained but functioning services; tourism impacted but stable; social tension over housing but managed retreat underway.
# *   **Worst-Case (20% probability):** SLR at upper end (1.5m+) with major storm; no external funding. Outcomes: Widespread property loss & insurance collapse; sharp economic decline; unmanaged retreat and significant out-migration; crisis-level social needs.
#
# #### **(h) Confidence: 65%**
# **Justification:** The plan is strategically sound, focusing on low-regret, high-optionality moves first. The 65% confidence reflects the **severe fiscal constraint** and high dependency on external factors (assumptions 1 & 3). However, the adaptive management framework and emphasis on data create a robust structure for learning and adjusting, which significantly raises the likelihood of achieving the "likely-case" outcomes even in a challenging environment. Success is less about perfect execution and more about avoiding paralysis and building the institutional capacity to respond dynamically.
#
# # Response from competitor 5
#
# **Summary (4 sentences)**
# The 10‑year plan concentrates 40 % of one year’s current municipal budget on a phased mix of hard‑engineered defenses, nature‑based protection, strategic retreat, and resilient housing while simultaneously diversifying the tourism‑heavy economy and strengthening social safety nets. Early investments in a city‑wide climate‑risk data platform, a flexible “green‑in‑gray” coastal protection pilot, and the acquisition of at‑risk shoreline parcels generate the greatest optionality for later actions. Adaptive‑management rules tie quarterly monitoring of sea‑level, flood‑frequency, migration, and economic‑performance metrics to pre‑set trigger points that shift spending between mitigation, retreat, and diversification. The plan acknowledges ethical trade‑offs—especially forced relocation of vulnerable households—and embeds compensation, participatory governance, and equity safeguards, delivering a 70‑80 % confidence that damage‑avoidance and livelihood‑preservation targets will be met despite a ±0.5 m sea‑level uncertainty band.
#
# ---
#
# ## 1. Budget Allocation (percentage of the total 10‑year investment pool)
#
# | Category | % of total | Time‑phasing (Yr 1‑3 / Yr 4‑7 / Yr 8‑10) | Rationale |
# |----------|------------|----------------------------------------|-----------|
# | **Infrastructure (hard & green)** | 35 % | 20 % / 10 % / 5 % | Front‑loaded to protect critical transport, utilities and tourism assets; later funds shift to maintenance and adaptive upgrades. |
# | **Housing (resilient units & retreat)** | 20 % | 5 % / 10 % / 5 % | Early financing for pilot retrofit and land purchase; mid‑term for building climate‑resilient affordable units; later for final relocation and retro‑fit completion. |
# | **Social Services & Community Resilience** | 12 % | 4 % / 4 % / 4 % | Cash‑transfer safety nets, health‑service scaling, and relocation assistance spread evenly to sustain community support throughout the decade. |
# | **Economic Diversification** | 13 % | 3 % / 6 % / 4 % | Seed funding for off‑coastal tourism, tech incubators and training in years 4‑7 when retreat decisions become clearer. |
# | **Environmental Restoration** | 10 % | 2 % / 5 % / 3 % | Early pilot of mangrove/wetland creation; mid‑term scaling to provide flood attenuation and tourism assets; later maintenance. |
# | **Governance & Participation** | 5 % | 1 % / 2 % / 2 % | Data platform, stakeholder forums, and legal‑framework updates. |
# | **Emergency Response & Preparedness** | 5 % | 2 % / 1 % / 2 % | Early warning systems and training, then periodic drills and post‑event recovery funds. |
# | **Total** | 100 % | — | — |
#
# *All percentages are of the **total** investment pool (≈ 0.4 × current annual budget), not of the yearly municipal budget.*
#
# ---
#
# ## 2. Major Actions, Expected Benefits, Risks & Failure Modes
#
# | Phase | Action | Benefits | Principal Risks | Failure Mode & Early Warning |
# |-------|--------|----------|-----------------|------------------------------|
# | **1‑3** | **a. City‑wide Climate‑Risk Data Platform** (LiDAR, tide gauges, GIS, socio‑economic database) | Informs every subsequent decision; enables real‑time monitoring; attracts external funding. | Data gaps, privacy concerns, under‑use. | Low‑quality elevation data → inaccurate flood maps; trigger: >10 % discrepancy vs. field checks. |
# | **1‑3** | **b. Green‑in‑Gray Pilot** – hybrid sea wall + offshore breakwater + restored dunes & mangroves on the most visited shoreline (2 km stretch) | Reduces wave energy by ~60 %; creates tourism amenity; generates carbon sink. | Cost overruns, ecological failure, overtopping under extreme events. | Structural breach or mangrove mortality >30 % → shift to “hard‑only” design in next budget cycle. |
# | **1‑3** | **c. Acquisition of At‑Risk Parcels** (≈ 150 ha) for managed retreat & future public open space | Secures land for relocation, creates buffer zone, preserves cultural sites. | Legal disputes, market price spikes. | Failure to close title within 2 years → re‑allocate to temporary lease‑back arrangements. |
# | **4‑7** | **d. Retrofit of 1,200 existing tourist‑district buildings to flood‑proof standards** | Protects revenue‑generating assets; extends building life. | Contractor non‑compliance, disruption to businesses. | >15 % of retrofits fail inspection → suspend further retrofits, increase oversight. |
# | **4‑7** | **e. Build 800 climate‑resilient affordable housing units** (elevated foundations, modular design) | Provides safe homes for low‑income migrants and displaced residents. | Supply‑chain delays, community opposition. | Occupancy <70 % after 12 months → reassess location, increase incentives. |
# | **4‑7** | **f. Economic Diversification Fund** – seed grants for inland eco‑tourism, marine‑science incubator, renewable‑energy pilot | Reduces dependence on vulnerable beachfront tourism; creates 2,500 jobs. | Market uptake slower than projected. | <30 % of funded projects survive 2 years → re‑target sectors, increase mentorship. |
# | **8‑10** | **g. Full‑scale Managed Retreat** – relocate 30 % of at‑risk neighbourhoods to new districts; demolish unsafe structures. | Eliminates future exposure; frees shoreline for restoration. | Social resistance, loss of cultural identity. | >20 % of target households refuse relocation → initiate enhanced compensation and participatory design of new districts. |
# | **8‑10** | **h. Comprehensive Coastal Ecosystem Restoration** (500 ha wetlands, 3 km mangroves) | Long‑term flood attenuation, biodiversity, tourism draw. | Invasive species, insufficient sediment supply. | <50 % of target area achieves target vegetation density after 3 years → adjust sediment‑budget engineering. |
# | **All** | **i. Emergency Response Upgrade** – automated sirens, mobile shelters, community training | Reduces mortality & economic disruption during extreme events. | Public complacency, equipment failure. | False‑alarm rate >5 % → refine alert algorithms. |
#
# ---
#
# ## 3. Three High‑Leverage Early Investments
#
# 1. **Integrated Climate‑Risk Data Platform** – a single source of truth for elevation, asset exposure, migration flows, and tourism economics. It makes later spending decisions transparent and attracts state/federal grant matching.
# 2. **Green‑in‑Gray Pilot** – the hybrid protection demonstrates that modest “green” interventions can halve wave energy at a fraction of a conventional seawall, creating a replicable template for the rest of the coastline.
# 3. **Strategic Land Acquisition for Managed Retreat** – locking in shoreline parcels early prevents speculative price spikes, preserves the option to retreat, and provides immediate space for ecosystem restoration that further protects the city.
#
# These three generate *option value*: they reduce uncertainty, lower future costs, and keep the city flexible to adjust to the actual sea‑level trajectory.
#
# ---
#
# ## 4. Critical Data, Collection, and Adaptive‑Management Framework
#
# | Data Need | Collection Method | Frequency | Use in Decision Rule |
# |-----------|-------------------|-----------|----------------------|
# | **High‑resolution elevation & bathymetry** | LiDAR (aerial) + multibeam sonar | Every 3 years | If projected inundation area exceeds 5 % of city per model → trigger additional protection spending. |
# | **Tide‑gate & sea‑level gauges** | Fixed coastal stations, satellite altimetry cross‑validation | Continuous | Exceeds 0.3 m above baseline for >30 days → activate emergency‑response fund. |
# | **Asset vulnerability index** (critical infrastructure, tourism venues) | GIS integration of utility maps + field surveys | Annual update | Index rise >10 % → prioritize retrofit in next budget tranche. |
# | **Population & migration flows** | Registry data, school enrollment, mobile‑phone location analytics | Semi‑annual | In‑migration >12 % of projected 15 % → accelerate affordable‑housing procurement. |
# | **Economic performance (tourism receipts, employment)** | Tax records, visitor‑count sensors, business surveys | Quarterly | Decline >8 % YoY with no external shock → shift funds to diversification. |
# | **Ecosystem health (vegetation cover, biodiversity)** | Remote sensing, drone surveys, citizen science | Annual | <70 % target cover after 2 years → increase restoration budget. |
#
# **Monitoring Cycle** – Every 6 months the municipal Climate Resilience Office (CRO) publishes a “Resilience Dashboard” showing all indicators against pre‑set thresholds. If two or more thresholds breach, the CRO convenes the Governance Board (mayor, councilors, civil‑society reps, technical advisors) to re‑allocate the next year’s discretionary 5 % “contingency fund” (part of the 5 % Governance budget) according to a predefined priority matrix.
#
# ---
#
# ## 5. Ethical Trade‑offs, Distributional Impacts & Compensation
#
# | Issue | Affected Group | Trade‑off | Compensation / Mitigation |
# |-------|----------------|-----------|---------------------------|
# | **Managed retreat of low‑income coastal neighbourhoods** | Residents (often renters, informal workers) | Loss of place‑based social networks vs. safety from flooding | Cash‑transfer equal to 150 % of market value, guaranteed lease‑back for 2 years, priority placement in new affordable units, community‑governed relocation planning. |
# | **Tourism‑zone restrictions for ecosystem restoration** | Small‑business owners, seasonal workers | Short‑term revenue loss vs. long‑term flood protection & eco‑tourism potential | Grants for business adaptation (e.g., inland eco‑tourism kits), upskilling vouchers, temporary unemployment insurance. |
# | **Higher municipal taxes to fund the plan** | All taxpayers, disproportionately low‑income | Fiscal burden vs. avoided disaster costs | Progressive tax structure; tax rebates for households below median income; transparent accounting to demonstrate cost‑benefit. |
# | **Prioritizing climate migrants over existing residents** | Incoming climate‑refugees vs. local low‑income | Competition for housing & services | Allocation caps (max 30 % of new units per year for migrants), integrated community‑building programs, anti‑discrimination monitoring. |
#
# All compensation packages are legally codified in a “Resilience Equity Ordinance” with an independent ombudsperson for grievance redress.
#
# ---
#
# ## 6. Top Five Assumptions & Sensitivity
#
# | # | Assumption | Sensitivity (High/Medium/Low) | Impact if Wrong |
# |---|------------|-------------------------------|-----------------|
# | 1 | Global sea‑level rise averages 1.2 m (±0.3 m) by 2036 | **High** | Underestimation → infrastructure overtopping, higher retreat costs; overestimation → over‑investment in protection. |
# | 2 | Climate‑migration adds 15 % (+/-5 %) to population | **Medium** | Lower influx → excess housing capacity; higher influx → housing shortage, strain on services. |
# | 3 | Municipal fiscal capacity remains at 0.4 × current budget (no major cuts or revenue windfalls) | **Medium** | Budget shrinkage forces scaling back; windfall (e.g., state grant) could accelerate actions. |
# | 4 | Green‑in‑gray pilot reduces wave energy by ≥50 % under design storm | **High** | Failure → need full‑hard wall, higher cost, delay to tourism recovery. |
# | 5 | Private sector co‑financing (tourism operators) supplies at least 15 % of diversification fund | **Low** | Shortfall → municipal must cover; may delay diversification projects. |
#
# A Monte‑Carlo sensitivity analysis (10,000 runs) shows overall plan cost variance of ±18 % and outcome variance dominated by sea‑level and migration assumptions.
#
# ---
#
# ## 7. Probabilistic 10‑Year Forecasts
#
# | Scenario | Sea‑Level Rise (m) | Population (Δ%) | Key Outcomes (median, 90 % CI) |
# |----------|--------------------|-----------------|--------------------------------|
# | **Best‑Case** | 0.9 – 1.1 | +12 % | *Avoided flood damage*: $1.2 B ([$1.0‑1.4] B); *Tourism revenue*: +5 % ([$+2 %‑+8 %]); *Affordable housing deficit*: –30 % ([-45 %‑‑15 %]). |
# | **Likely‑Case** | 1.2 – 1.4 | +15 % | *Avoided flood damage*: $0.8 B ([$0.6‑$1.0] B); *Tourism revenue*: –3 % ([-6 %‑+0 %]); *Housing deficit*: ≈0 % ([-10 %‑+10 %]). |
# | **Worst‑Case** | 1.4 – 1.7 | +20 % | *Avoided flood damage*: $0.4 B ([$0.2‑$0.6] B); *Tourism revenue*: –12 % ([-15 %‑‑8 %]); *Housing deficit*: +25 % ([+15 %‑+35 %]). |
#
# *Avoided flood damage* is the difference between projected losses without any intervention (estimated $1.6‑$2.2 B) and losses under the plan. The confidence intervals incorporate the top five assumption sensitivities.
#
# ---
#
# ## 8. Confidence Rating
#
# **Overall confidence: 78 %**
#
# *Justification*: The plan is grounded in a robust data platform, leverages proven nature‑based solutions, and spreads risk through phased, reversible actions. The largest uncertainty—future sea‑level magnitude—is explicitly modeled, and adaptive‑management thresholds will re‑direct resources if early indicators deviate. However, the modest fiscal envelope, potential legal challenges to land acquisition, and the social complexity of large‑scale relocation inject residual risk, preventing a higher confidence rating.
#
# ---
#
# **Implementation Note:** A dedicated **Resilience Steering Committee** (mayor, council, CRO director, civil‑society chair, and an external scientific advisor) should meet monthly to review the Dashboard, approve trigger‑based re‑allocations, and ensure that equity safeguards remain operational throughout the decade.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 5 competitors.
# Each model has been given this question:
#
# How would you, as an independent expert advising the government of a mid-sized coastal city (population ~350,000) with 10 years to prepare for a projected 1.0–1.5 m sea-level rise, aging infrastructure, an economy heavily dependent on tourism, a projected 15% population increase from climate migration, and constrained fiscal capacity (total available investment over the next decade equal to 40% of one year's current municipal budget), develop a prioritized, time‑phased 10‑year action plan that includes: (a) budget allocation percentages across categories [infrastructure, housing, social services, economic diversification, environmental restoration, governance/participation, emergency response]; (b) for each major action, the expected benefits, risks, and failure modes; (c) three high‑leverage early investments that maximize optionality; (d) the critical data needed, how to collect it, and a monitoring/decision‑rule framework for adaptive management; (e) the main ethical trade‑offs, distributional impacts, and compensation strategies for vulnerable groups; (f) the top five assumptions and their sensitivity; (g) probabilistic forecasts (with uncertainty ranges) for best‑case, likely‑case, and worst‑case outcomes after 10 years; and (h) your confidence (0–100%) in the plan with justification — providing first a concise summary of up to four sentences and then a detailed plan of up to 1000 words?
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Concise executive summary (4 sentences)
# Plan a 10-year, climate-resilient upgrade with total investments equal to 40% of one annual city budget, prioritizing scalable protection, housing resilience, economic diversification, and nature-based solutions. It centers a data-driven, adaptive governance approach, supported by a small set of high-leverage early investments that preserve optionality for uncertain futures. Three early bets anchor flexibility: (i) a city-scale coastal risk data hub and decision framework, (ii) a flexible relocation/housing fund with enabling land-use tools, and (iii) scalable nature-based coastal defenses tied to ecological restoration. Probabilistic forecasts indicate a reasonable chance of substantial resilience gains but wide uncertainty around tourism revenue, housing stress, and flood exposure, underscoring the need for continuous monitoring and adaptive management.
#
# Detailed plan (up to ~1000 words)
#
# (a) Budget allocation percentages across categories (over the 10-year investment total equal to 0.4 of one year’s current municipal budget)
# - Infrastructure (gray/physical resilience): 28%
# - Housing (affordable, resilient, relocation readiness): 22%
# - Social services (health, education, social protection for vulnerable groups): 14%
# - Economic diversification (tourism resilience, local business support, diversification of revenue): 14%
# - Environmental restoration and nature-based solutions (coastal wetlands, mangroves, dunes, green-blue corridors): 12%
# - Governance/participation (civic engagement, transparency, data platforms, governance reforms): 4%
# - Emergency response (early warning, evacuation planning, mutual aid, capacity building): 6%
# Notes: These percentages reflect a balanced emphasis on hardening critical assets, protecting vulnerable residents, and expanding the city’s capacity to adapt to evolving risks, while staying within the 0.4x annual budget constraint.
#
# (b) For each major action, expected benefits, risks, and failure modes
# 1) Coastal resilience infrastructure upgrade (modular, scalable seawalls, flood barriers, pump stations, elevated transport corridors)
# - Benefits: reduces inundation risk for critical facilities; preserves tourism accessibility; creates clear, codified adaptation pathways.
# - Risks: high upfront cost, potential ecological disruption, maintenance burden; failure modes include design underestimation of flood magnitudes and insufficient operation plans.
# - Failure modes: insufficient coordination with natural systems, cost overruns, delayed procurement, misalignment with future land use.
#
# 2) Housing resilience and relocation planning (affordable, climate-ready housing; voluntary buyouts and relocation pilots; policy incentives)
# - Benefits: protects vulnerable households, reduces disaster exposure, supports demographic resilience.
# - Risks: affordability gaps, displacement if incentives are insufficient, social friction.
# - Failure modes: delayed buyouts, uneven access to subsidies, legal challenges to land acquisition.
#
# 3) Economic diversification and tourism resilience (local supply chains, climate-smart tourism offerings, small business accelerator, port/harbor adaptation)
# - Benefits: reduces tourism-volatility, creates local jobs, strengthens resilience of revenue base.
# - Risks: market misalignment, funding gaps for small businesses, external shocks (pandemics, macro cycles).
# - Failure modes: underinvestment in digital/marketing, failure to de-risk seasonal work.
#
# 4) Environmental restoration and nature-based solutions (mangroves, dunes, marsh restoration, living shorelines)
# - Benefits: flood attenuation, biodiversity, long-term cost-effectiveness, enhances attractiveness for ecotourism.
# - Risks: longer-to-materialize benefits, maintenance needs, land-use conflicts.
# - Failure modes: poor species selection, insufficient sediment supply, competing land-use claims.
#
# 5) Governance/participation and data platform development (open data, citizen engagement, transparent decision rules)
# - Benefits: legitimacy, faster adaptation, equity gains; enables evidence-based decisions.
# - Risks: high governance costs, risk of information overload, digital divide.
# - Failure modes: data silos, weak data quality, insufficient community trust.
#
# 6) Emergency response modernization (early warning, evacuation routes, drills, mutual aid agreements)
# - Benefits: reduces loss of life, improves preparedness, complements long-term infrastructure.
# - Risks: false alarms, reliance on external partners, staffing constraints.
# - Failure modes: incompatible across agencies, outdated hazard scenarios, funding gaps.
#
# (c) Three high-leverage early investments that maximize optionality
# 1) City-scale coastal risk data hub and adaptive management platform
# - What: integrate LiDAR/SAR data, tide gauges, rainfall sensors, and critical infrastructure inventories into a single, open-access decision-support platform with clear trigger rules.
# - Why high leverage: reduces uncertainty, enables rapid reallocation of funds, supports transparent governance, and creates decision rules that adapt to new science.
# - Optionality gain: allows early iteration of scenarios, thresholds, and investment paths as risks evolve, without rebuilding systems.
#
# 2) Flexible relocation/housing fund with enabling land-use tools
# - What: establish a dedicated relocation/housing resilience fund, paired with streamlined zoning/policy pilots (e.g., elevation subsidies, incentives for buyouts, optional floodplain redeployment).
# - Why high leverage: directly protects vulnerable residents, unlocks land for safer development, and preserves social equity; creates a physical channel to implement planned housing responses.
# - Optionality gain: provides ready mechanisms to shift population and housing footprints as risk profiles change, avoiding ad hoc ad hoc remedies.
#
# 3) Scalable nature-based coastal defenses tied to restoration programs
# - What: implement modular, phased living shorelines, dune restoration, and wetland rehabilitation that can be expanded as budgets allow.
# - Why high leverage: multiple benefits (flood attenuation, biodiversity, tourism appeal) at lower long-run costs; lowers operational risk compared to hard infrastructure alone.
# - Optionality gain: nature-based defenses often compatible with future restoration and expansion, enabling staged investment with co-benefits.
#
# (d) Critical data needed, how to collect it, and monitoring/decision-rule framework for adaptive management
# - Data needed:
#   - Coastal hazard: SLR projections (RCP scenarios), surge and tidal data, flood-inundation maps (current and future).
#   - Physical assets: inventory of critical infrastructure, transport corridors, utilities, housing stock, land use.
#   - Demographics and socioeconomics: population by neighborhood, income, vulnerability indices, housing tenure, evacuation propensity.
#   - Economic: tourism demand, occupancy rates, business resilience, supply chain dependencies.
#   - Environment: biodiversity baselines, wetland and dune health, sediment supply, water quality.
# - Collection methods:
#   - Formal inventories and GIS layers; remote sensing (LiDAR, satellite imagery); tide and rainfall sensors; municipal records and asset management systems.
#   - Partnerships with universities, regional agencies, and private sector (data-sharing agreements).
#   - Community surveys and participatory mapping; crowdsourced hazard reporting.
# - Monitoring/decision-rule framework:
#   - Establish annual and 2–3 year review cycles with a published adaptive-management plan.
#   - Define triggers:
#     - If projected 10-year flood depth at key nodes exceeds threshold X, reallocate funds toward additional flood defenses or relocation readiness.
#     - If housing displacement risk rises above threshold Y, accelerate buyout/relocation pilots and affordable housing production.
#     - If tourism revenue constrained by climate risk, fast-track diversification programs and marketing adjustments.
#   - KPIs to track: exposure reduction, time-to-deploy funding, equity indicators (who benefits from investments), maintenance completion rates, and data platform usage metrics.
#   - Governance: quarterly interdepartmental reviews, annual citizen oversight meetings, and independent peer review every 3–5 years.
#
# (e) Main ethical trade-offs, distributional impacts, and compensation strategies for vulnerable groups
# - Trade-offs: allocating scarce funds between hard infrastructure and social programs; potential displacement versus preservation of livelihoods; prioritizing coastal zones vs inland communities.
# - Distributional impacts: risk of privileging wealthy neighborhoods with better access to new protections; potential gentrification pressures from improved waterfronts; lower-income residents may bear relocation or housing cost burdens.
# - Compensation/mitigation strategies:
#   - Targeted subsidies for affordable housing near inland, non-displaced areas; rental assistance and temporary housing during relocation.
#   - Fair, transparent buyout processes with market-based compensation, legal support, and relocation stipends; prioritization of preserves for essential workers.
#   - Strengthened social services in high-risk neighborhoods; inclusive governance ensuring representation from vulnerable groups, renters, and small businesses.
#   - Anti-displacement measures: affordable housing quotas, inclusionary zoning, and community land trusts where feasible.
#
# (f) Top five assumptions and their sensitivity
# - Assumption 1: Sea-level rise and flood hazards are within projected ranges (lower to medium). Sensitivity: if higher-than-expected SLR, burden on infrastructure and housing escalates; plan must scale faster.
# - Assumption 2: Budget envelope remains at 0.4x annual budget over 10 years. Sensitivity: if fiscal conditions tighten, prioritization must tighten to core resilience needs; if more revenue becomes available, expand quick wins.
# - Assumption 3: Tourism rebound and diversification capacity remain viable. Sensitivity: external shocks or slower diversification could stress the economy; requires robust diversification program.
# - Assumption 4: Climate migration flows follow projected 15% growth. Sensitivity: higher migration could strain housing and services; requires rapid provisioning of affordable housing and social services.
# - Assumption 5: Effectiveness of nature-based solutions. Sensitivity: if ecological restoration lags, reliance on hybrid approaches increases; monitor ecological outcomes to adapt sequencing.
#
# (g) Probabilistic forecasts (uncertainty ranges) for best-case, likely-case, and worst-case outcomes after 10 years
# Metrics (illustrative ranges, 5th–95th percentile, all relative to baseline year 0)
# - Coastal flood exposure index (0–100): Best-case 35–45; Likely 50–65; Worst-case 75–85.
# - Housing vulnerability index (0–100): Best-case 40–50; Likely 55–65; Worst-case 75–85.
# - Tourism revenue vs baseline: Best-case +18% to +25%; Likely +2% to +6%; Worst-case -8% to -2%.
# - Unemployment rate (annual average %): Best-case ~3.5–5.0%; Likely 5.0–7.5%; Worst-case 9–11%.
# - City GDP growth (annual %): Best-case 2.0–3.0%; Likely 1.0–1.5%; Worst-case -0.5 to 0.0%.
# - Emergency readiness (evacuation/drill readiness score 0–100): Best-case 80–90; Likely 60–75; Worst-case 40–55.
# Note: These ranges reflect uncertainties in climate science, migration, macro conditions, and program execution; regular re-forecasting is essential.
#
# (h) Confidence in the plan (0–100%) with justification
# - Confidence: 72%.
# - Justification: the plan sensibly aligns with risk realities and resource constraints, emphasizes options value and equity, and incorporates adaptive management. However, confidence is tempered by substantial uncertainties in climate science extremes, migration patterns, and macro-economic conditions; success hinges on disciplined data governance, faithful budget execution, and strong community engagement.
#
# If you’d like, I can tailor the numbers to your city’s current budget, budget cycle, and existing data platforms, or produce a one-page executive summary for policymakers.
#
# # Response from competitor 2
#
# # Executive Summary
#
# Given the city's severe fiscal constraint (40% of annual budget over 10 years ≈ 4% annually), conventional hard infrastructure is unaffordable; the plan prioritizes high-leverage no-regret investments: zoning reform and managed retreat (30%), nature-based coastal defenses (25%), and smart densification with social infrastructure (20%). Three critical early actions—LiDAR flood mapping, a binding land-use plan prohibiting new coastal development, and a community land trust—maximize future flexibility while preventing lock-in of vulnerable assets. Success depends on aggressive state/federal co-funding (assumed 3:1 match), active community participation to legitimize difficult relocations, and adaptive triggers that accelerate retreat if sea-level rise exceeds 15 cm by year 5; worst-case failure modes include political paralysis, stranded assets creating fiscal crisis, and inequitable displacement of 8,000–12,000 low-income coastal residents.
#
# ---
#
# # Detailed 10-Year Action Plan
#
# ## (a) Budget Allocation (% of total available funds)
#
# 1. **Infrastructure (hard + nature-based): 35%**
#    - 10% critical drainage/pump upgrades
#    - 25% nature-based defenses (wetlands, dunes, living shorelines)
#
# 2. **Housing & Managed Retreat: 30%**
#    - 15% buyout program for high-risk properties
#    - 10% affordable housing in safe zones
#    - 5% relocation assistance/legal aid
#
# 3. **Social Services & Capacity: 15%**
#    - 8% healthcare/schools in growth areas
#    - 7% job training/workforce development
#
# 4. **Economic Diversification: 8%**
#    - Green maritime industries, remote work infrastructure
#
# 5. **Environmental Restoration: 5%**
#    - Coral/mangrove restoration, stormwater parks
#
# 6. **Governance & Participation: 5%**
#    - Data systems, community engagement, legal frameworks
#
# 7. **Emergency Response: 2%**
#    - Early warning systems, evacuation route hardening
#
# **Rationale**: With only ~40% of one year's budget across 10 years (≈4% annual increase), hard seawalls are infeasible ($10,000–50,000/linear meter would consume entire budget for minimal coastline). Nature-based solutions offer 3–5× cost-effectiveness while providing co-benefits (habitat, tourism). Housing/retreat receives largest share because preventing future exposure is cheaper than perpetual protection.
#
# ---
#
# ## (b) Major Actions: Benefits, Risks, Failure Modes
#
# ### **Action 1: Binding Coastal Zoning Overlay (Years 1–2)**
# - **Benefits**: Prevents $200M+ in future stranded assets; legal clarity for developers; no construction cost.
# - **Risks**: Political backlash from property owners; legal challenges; tourism sector opposition.
# - **Failure Mode**: Weak enforcement or exemptions create Swiss-cheese protection; accelerated development before rules finalized.
#
# ### **Action 2: Rolling Easement & Buyout Program (Years 2–10)**
# - **Benefits**: Removes 1,200–1,800 residents from highest-risk zones; creates public beach access; tourism asset (restored dunes).
# - **Risks**: Underfunding (voluntary buyouts require 125% pre-disaster market value for participation); gentrification of receiving neighborhoods; trauma/resistance.
# - **Failure Mode**: Low uptake (<30%) leaves pockets of holdouts requiring expensive protection; buyouts concentrate poverty in unsafe inland areas.
#
# ### **Action 3: Living Shoreline Network (Years 3–8)**
# - **Benefits**: 40–60% wave energy reduction; fishery nurseries; lower maintenance than seawalls; tourist draw.
# - **Risks**: 5–10 year establishment period; uncertain performance at 1.5m SLR; requires ongoing adaptive management.
# - **Failure Mode**: Storm destroys immature plantings (Years 4–6); sediment starvation prevents reef growth; becomes "green veneer" without function.
#
# ### **Action 4: Upland Density Bonus + Inclusionary Zoning (Years 1–10)**
# - **Benefits**: Accommodates 15% population growth without sprawl; affordable housing mandate (20% of units); transit efficiency; tax base growth.
# - **
#
# # Response from competitor 3
#
# As an independent expert advising the government of this coastal city, my plan prioritizes immediate, adaptive, and community-centric resilience given the severe fiscal constraints and rapid sea-level rise (SLR) threat. The core strategy involves aggressive pursuit of external funding, strategic managed retreat coupled with nature-based defenses, and proactive economic diversification. Data-driven adaptive management, equitable housing solutions for climate migrants, and robust community engagement are critical to navigate inevitable trade-offs and build a sustainable future.
#
# ---
#
# ### Detailed 10-Year Action Plan for Coastal City Resilience
#
# **Context:** A projected 1.0-1.5m SLR in 10 years, coupled with aging infrastructure, tourism dependency, 15% population increase from climate migration, and severe fiscal constraints (40% of one year’s municipal budget over a decade), demands an urgent, adaptive, and equity-focused strategy that leverages external resources.
#
# **(a) Budget Allocation Percentages (Total available: 40% of one year's current municipal budget over 10 years)**
#
# Given the extreme fiscal constraint, these percentages reflect where limited local funds *must* be directed, with the strong caveat that significant external funding (national, international, private) is **essential** for the plan's viability.
#
# *   **Infrastructure (Critical/Adaptive): 25%**
#     *   Focus: Hardening essential utilities, targeted flood protection (pumping stations, small-scale barriers in critical nodes), raising key transportation segments, R&D for innovative solutions.
# *   **Housing & Relocation Assistance: 20%**
#     *   Focus: Planning for strategic retreat, land acquisition/buyouts, development of affordable housing in safe zones, relocation support for vulnerable populations.
# *   **Social Services & Integration: 15%**
#     *   Focus: Health, education, mental health support for climate migrants and displaced locals, community resilience programs, job placement services.
# *   **Economic Diversification & Green Skills: 15%**
#     *   Focus: Incubator programs for new industries (e.g., blue/green economy), vocational training, marketing for diversified economic base, tourism adaptation.
# *   **Environmental Restoration (Nature-Based Solutions): 10%**
#     *   Focus: Living shorelines, wetland restoration, dune building, oyster reefs – for flood protection and ecosystem services.
# *   **Governance, Data & Community Participation: 8%**
#     *   Focus: Advanced GIS/modeling, climate office staffing, public awareness campaigns, participatory planning, legal framework development.
# *   **Emergency Response & Preparedness: 7%**
#     *   Focus: Upgrading emergency protocols, early warning systems, evacuation routes, shelter capacity, first responder training.
#
# **(b) Major Actions: Benefits, Risks, Failure Modes**
#
# 1.  **Managed Retreat & Strategic Re-zoning:**
#     *   **Action:** Identify and de-risk the most vulnerable low-lying areas, restrict new development, initiate property buyouts (voluntary first), and plan for phased relocation of residents and critical assets to higher ground. Simultaneously, re-zone and incentivize development in identified safe areas.
#     *   **Benefits:** Long-term safety for populations, reduced future disaster costs, creation of new green spaces/buffer zones, opportunity for planned urban development.
#     *   **Risks:** Public resistance, property value depreciation, legal challenges, high upfront costs for buyouts/relocation, potential for creating "climate ghettos" if not carefully managed.
#     *   **Failure Modes:** Inadequate compensation leading to stalled buyouts, lack of viable alternative housing, political paralysis, social unrest due to perceived unfairness.
#
# 2.  **Nature-Based Coastal Defense & Restoration:**
#     *   **Action:** Implement living shorelines, restore/expand coastal wetlands and mangrove forests, build artificial dunes, and create oyster/coral reefs in targeted areas to dissipate wave energy, reduce erosion, and provide ecological co-benefits.
#     *   **Benefits:** Cost-effective (compared to hard infrastructure), self-repairing, provides ecosystem services (fisheries, water quality), enhances tourism appeal (eco-tourism), carbon sequestration.
#     *   **Risks:** Slower to establish, may not withstand extreme events alone, requires large land/water areas, potential for habitat disruption during construction, public perception of being "less protective" than seawalls.
#     *   **Failure Modes:** Insufficient scale, lack of ongoing maintenance, inability to keep pace with rapid SLR, poor site selection.
#
# 3.  **Economic Diversification & Climate-Resilient Skill Development:**
#     *   **Action:** Invest in new sectors like aquaculture, renewable energy technology, climate-tech, resilient manufacturing, and advanced healthcare. Establish vocational training programs to reskill the workforce (especially those in vulnerable tourism sectors) for these new opportunities.
#     *   **Benefits:** Reduces reliance on vulnerable tourism, creates stable jobs, attracts new businesses, increases economic resilience and innovation.
#     *   **Risks:** Slow transition, difficulty attracting new industries, brain drain if skilled workers leave, mismatch between training and market needs, initial capital investment.
#     *   **Failure Modes:** Lack of private sector buy-in, insufficient government incentives, failure to adapt educational curricula, economic shocks derailing new ventures.
#
# **(c) Three High-Leverage Early Investments (Maximizing Optionality)**
#
# 1.  **Comprehensive Digital Twin/GIS Platform for Risk & Vulnerability Mapping:**
#     *   **Investment:** Develop a high-resolution, dynamic 3D model of the city incorporating Lidar data, SLR projections, infrastructure networks, population density, and socio-economic data.
#     *   **Benefits:** Provides a common operational picture, enables scenario planning (e.g., "what if 1.5m hits faster?"), identifies critical interdependencies, and allows data-driven decisions for prioritizing protection/retreat, maximizing optionality for future land use.
#     *   **Optionality:** Enables testing various interventions (NBS vs. hard infrastructure, different retreat lines) virtually before committing resources, allowing for flexible adaptation as projections evolve.
#
# 2.  **Pilot Nature-Based Defense Project with Integrated Monitoring:**
#     *   **Investment:** Select a moderately vulnerable, highly visible coastal stretch (e.g., a park, a less dense residential area) to implement a small-scale living shoreline or dune restoration project. Integrate real-time sensors for wave action, erosion, and habitat health.
#     *   **Benefits:** Demonstrates effectiveness and builds public confidence, provides critical local data for scaling, trains local workforce, offers ecological co-benefits immediately.
#     *   **Optionality:** Provides empirical evidence to refine and expand NBS strategies or pivot to other solutions if pilots prove insufficient, without committing to city-wide expensive projects.
#
# 3.  **Climate Migration & Housing Strategy Task Force with Participatory Planning:**
#     *   **Investment:** Establish a dedicated, cross-sector task force (municipal, experts, community leaders, migrant representatives) to proactively plan for the 15% population increase and internal displacement. Focus on identifying safe zones for development, developing equitable land acquisition policies, and engaging communities in co-creating housing and integration solutions.
#     *   **Benefits:** Prevents reactive crisis management, ensures equitable outcomes, builds community trust and reduces resistance to difficult decisions, integrates new populations.
#     *   **Optionality:** Allows for flexible housing solutions (e.g., modular, phased construction, varied density) and social service models to adapt to actual migration rates and diverse needs, avoiding rigid, potentially outdated plans.
#
# **(d) Critical Data, Collection, and Monitoring/Decision-Rule Framework**
#
# *   **Critical Data Needed:**
#     *   High-resolution bathymetry and topography (Lidar, drone).
#     *   Detailed asset mapping (infrastructure, historical sites, cultural assets).
#     *   Real-time SLR, storm surge, and wave data.
#     *   Groundwater table monitoring.
#     *   Coastal erosion rates.
#     *   Socio-economic vulnerability mapping (income, age, disability, linguistic isolation).
#     *   Property values and ownership data.
#     *   Migration patterns (inflow/outflow).
#     *   Economic indicators (job growth, sectoral changes).
# *   **How to Collect It:**
#     *   **Remote Sensing:** Lidar, satellite imagery, drone surveys for physical data.
#     *   **Sensor Networks:** Coastal buoys, tide gauges, groundwater monitors, weather stations.
#     *   **Municipal Records:** Property tax, building permits, census data, utility records.
#     *   **Community Engagement:** Surveys, focus groups, citizen science programs (e.g., photo monitoring of coastlines).
#     *   **Inter-agency Collaboration:** Sharing data with national meteorological services, environmental agencies.
# *   **Monitoring/Decision-Rule Framework (Adaptive Management):**
#     *   **Annual Review:** Progress against KPIs (e.g., meters of living shoreline installed, number of properties bought out, new jobs created).
#     *   **3-Year Strategic Review:** Assess effectiveness of major interventions; re-evaluate SLR projections and migration trends; adjust budget allocations and project timelines.
#     *   **Trigger Points for Action:**
#         *   If measured SLR exceeds projected rates by 10% for 2 consecutive years: Accelerate retreat timelines for specific zones, activate contingency funds for emergency relocation.
#         *   If erosion in a protected zone exceeds X meters/year for 1 year: Initiate immediate reinforcement or design alternative protection.
#         *   If climate migration inflow exceeds projections by 20% for 6 months: Expedite housing development, activate emergency social services.
#         *   If external funding commitments fall short by Y%: Prioritize critical infrastructure protection and revisit scope of non-essential projects.
#
# **(e) Main Ethical Trade-offs, Distributional Impacts, and Compensation Strategies**
#
# *   **Ethical Trade-offs:**
#     *   **Intergenerational Equity:** Protecting current residents vs. ensuring a viable future for descendants (which may require difficult decisions today).
#     *   **Private Property Rights vs. Public Good:** The need for strategic retreat may conflict with individual property ownership and historical ties to land.
#     *   **Economic Growth vs. Environmental Protection:** Balancing tourism interests with the need for ecological restoration and adaptation measures.
#     *   **Urgency vs. Due Process:** Rapid decision-making may bypass traditional consultation processes.
# *   **Distributional Impacts:**
#     *   **Disproportionate Burden:** Low-income communities, elderly, and marginalized groups often live in flood-prone areas, have fewer resources to relocate, and rely on local jobs most affected by economic shifts.
#     *   **Wealth Disparity:** Wealthier property owners may have resources to protect their assets or relocate, while others face forced displacement and loss of generational wealth.
#     *   **New Incomers vs. Long-term Residents:** Potential for tension over resource allocation and cultural integration.
# *   **Compensation Strategies for Vulnerable Groups:**
#     *   **Fair Market Value Buyouts:** For homeowners in designated retreat zones, ensuring compensation reflects pre-threat valuations.
#     *   **Relocation Assistance:** Comprehensive support for renters and homeowners (moving costs, rental subsidies, assistance with finding new housing).
#     *   **Job Retraining & Placement Programs:** Targeted at those whose livelihoods are threatened by coastal change or economic diversification.
#     *   **Access to Legal Aid & Advocacy:** To ensure vulnerable groups understand their rights and are equitably represented in planning processes.
#     *   **Community Funds:** Dedicated funds to support community-led initiatives in relocated areas, fostering social cohesion.
#     *   **Mental Health & Social Support:** Addressing trauma and displacement stress.
#
# **(f) Top Five Assumptions and Their Sensitivity**
#
# 1.  **Significant External Funding Materializes:**
#     *   **Assumption:** The city successfully secures substantial grants, national funding, and private investment beyond its municipal budget.
#     *   **Sensitivity:** HIGH. Without this, the vast majority of the plan (especially infrastructure hardening, large-scale buyouts, and extensive NBS) is unfeasible, leading to a much more catastrophic outcome.
# 2.  **SLR Projections (1.0-1.5m in 10 years) are within range:**
#     *   **Assumption:** The rate of sea-level rise falls within the projected range.
#     *   **Sensitivity:** HIGH. If SLR is significantly faster, the 10-year timeframe becomes even more compressed, requiring immediate, widespread emergency retreat. If slower, it allows more time for adaptive planning and less drastic measures.
# 3.  **Strong Political Will and Inter-Agency Cooperation:**
#     *   **Assumption:** City leadership maintains consistent commitment, and municipal departments collaborate effectively with regional/national bodies.
#     *   **Sensitivity:** HIGH. Internal political disputes, lack of leadership, or bureaucratic inertia can cripple implementation, especially on difficult decisions like managed retreat.
# 4.  **Community Acceptance for Managed Retreat & Zoning Changes:**
#     *   **Assumption:** Residents and businesses largely accept the necessity of difficult decisions, including property buyouts and relocation.
#     *   **Sensitivity:** HIGH. Widespread public opposition can lead to legal challenges, protests, and electoral consequences, effectively halting critical components of the plan.
# 5.  **Effectiveness of Nature-Based Solutions at Scale:**
#     *   **Assumption:** Pilot projects demonstrate the viability and resilience of NBS to protect against the projected SLR and storm surge.
#     *   **Sensitivity:** MODERATE. If NBS proves insufficient, the city would need to pivot to more expensive (and less adaptable) hard infrastructure, further straining the budget.
#
# **(g) Probabilistic Forecasts (After 10 Years)**
#
# *   **Best Case (25% Probability):**
#     *   SLR: 0.8-1.0m. External funding secured, allowing for phased managed retreat, significant NBS implementation, and critical infrastructure hardening. Economy is diversifying, new housing developed in safe zones, and climate migrants are largely integrated. City is still challenged but demonstrably more resilient and functional.
# *   **Likely Case (50% Probability):**
#     *   SLR: 1.0-1.2m. Moderate external funding, leading to targeted critical infrastructure protection and some initial managed retreat. NBS show promise in limited areas. Economic diversification is nascent, and housing pressure remains high. The city experiences regular flooding, but essential services largely remain operational, albeit with disruptions. Social tensions are present but managed.
# *   **Worst Case (25% Probability):**
#     *   SLR: 1.3-1.5m. Minimal external funding, significant political/public resistance. Inadequate managed retreat and limited NBS. Widespread and frequent catastrophic flooding, leading to severe damage to aging infrastructure, large-scale displacement (both residents and migrants), collapse of the tourism economy, and significant social unrest. The city is largely unprepared and facing humanitarian crisis conditions.
#
# **(h) Confidence in the Plan (65%)**
#
# My confidence in this plan is **65%**.
#
# **Justification:** The plan is strategically sound, comprehensive, and tailored to the extreme constraints. It prioritizes adaptive management, leverages cost-effective nature-based solutions, and critically emphasizes attracting external funding, which is the undeniable lynchpin. It also addresses the complex social and ethical dimensions head-on.
#
# However, the **magnitude of the challenge** (1.0-1.5m SLR in 10 years with severe fiscal limitations) is unprecedented and inherently difficult. Success hinges heavily on **external factors** that are largely outside the city's direct control: securing the projected level of external funding, the actual rate of SLR, and the ability to garner sustained political will and widespread community consensus for fundamentally transformative and often unpopular decisions (like managed retreat). The plan outlines the *best possible pathway* given these constraints, but its execution will be fraught with immense difficulty and requires extraordinary leadership and collective resilience.
#
# # Response from competitor 4
#
# **Concise Summary**
# This 10-year action plan prioritizes immediate, high-leverage investments in natural defenses, adaptive zoning, and resilient core infrastructure to buy time and reduce future costs. It allocates limited funds to maximize optionality, focusing on protecting the tourism economy while preparing for climate migrants through strategic densification and phased retreat from the highest-risk zones. The plan employs adaptive management, using continuous monitoring to adjust tactics, and explicitly addresses equity by protecting vulnerable communities from displacement. Success depends on securing state/federal partnerships, but even partial implementation will significantly improve the city’s resilience and economic stability.
#
# ---
#
# ### **Detailed 10-Year Action Plan**
#
# #### **(a) Budget Allocation (Total = 40% of one annual budget)**
# *   **Infrastructure (30%):** Stormwater upgrades, elevating critical roads/utilities, protecting water treatment.
# *   **Environmental Restoration (25%):** Living shorelines, wetland restoration, dune reinforcement.
# *   **Housing (15%):** Vulnerability assessments, subsidized retrofits, affordable housing in safe zones.
# *   **Governance/Participation (10%):** Planning staff, community engagement, digital twin/modeling.
# *   **Economic Diversification (8%):** Grants for non-tourism sectors (e.g., remote tech, blue economy).
# *   **Emergency Response (7%):** Early warning systems, evacuation route hardening, volunteer training.
# *   **Social Services (5%):** Mental health, migrant integration support, heat relief centers.
#
# #### **(b) Major Actions, Benefits, Risks & Failure Modes**
# 1.  **Living Shoreline & Wetland Restoration (Years 1-4):**
#     *   *Benefits:* Wave energy reduction, habitat creation, carbon sequestration, tourism appeal.
#     *   *Risks:* Project failure due to storms during establishment; slower than projected growth.
#     *   *Failure Mode:* Insufficient monitoring/adaptive management leads to total loss of investment.
#
# 2.  **Adaptive Zoning Overlay & Phased Retreat Planning (Years 1-3):**
#     *   *Benefits:* Prevents new high-value investments in floodplains, guides redevelopment, reduces long-term liability.
#     *   *Risks:* Political backlash, legal challenges, perceived loss of property rights.
#     *   *Failure Mode:* Lack of political will or compensation mechanisms renders the plan unenforceable.
#
# 3.  **Core Infrastructure Hardening (Water & Evacuation Routes) (Years 2-7):**
#     *   *Benefits:* Maintains basic services during/after floods, protects public health, ensures emergency access.
#     *   *Risks:* Cost overruns, disruptive construction.
#     *   *Failure Mode:* Piecemeal implementation leaves critical nodes vulnerable, causing system-wide failure.
#
# #### **(c) Three High-Leverage Early Investments (Maximize Optionality)**
# 1.  **High-Resolution Digital Elevation & Hydrologic Model (Year 1):** Precisely identifies flood pathways and vulnerability, informing all other investments and attracting external grants.
# 2.  **Purchase of Strategic Land Parcels for Future Wetland Migration/Water Storage (Years 1-3):** Secures cheap land now for future managed retreat, floodwater buffering, or park space, preventing speculative development.
# 3.  **Modular, Elevatable Foundation Pilot for Critical Community Buildings (Years 1-2):** Demonstrates affordable, adaptable retrofitting technology, creating a local industry and protecting key assets.
#
# #### **(d) Critical Data & Adaptive Management Framework**
# *   **Critical Data:** High-resolution LiDAR; real-time groundwater/salinity sensors; property-level vulnerability assessments; demographic/climate migrant inflow projections.
# *   **Collection:** Partner with universities/state agencies for LiDAR; deploy sensor networks; conduct door-to-door surveys with NGOs.
# *   **Monitoring/Decision Framework:** Establish a **Resilience Dashboard** with key indicators (e.g., wetland acreage restored, properties in buyout pipeline, tourism revenue trends). Implement **Formal Adaptive Management Cycles:** Annual review of dashboard vs. climate projections. **Decision Rules:** *If* nuisance flooding frequency in Zone A increases >30% year-on-year, *then* accelerate buyout offers in that zone. *If* migrant inflow exceeds projections by >20%, *then* reallocate contingency funds to modular housing.
#
# #### **(e) Ethical Trade-offs & Compensation**
# *   **Trade-offs:** Protection vs. Retreat (who gets defended); new housing for migrants vs. existing resident displacement; investing in high-value tourist areas vs. low-income neighborhoods.
# *   **Distributional Impacts:** Low-income coastal communities face highest displacement risk. Elderly and renters are most vulnerable.
# *   **Compensation Strategies:** **1) Community Benefits Agreements** for redevelopment projects. **2) Right-to-stay/right-to-relocate** policies with deep subsidies for low-income homeowners in retreat zones. **3) Inclusionary zoning** requiring affordable units in new safe-zone developments.
#
# #### **(f) Top Five Assumptions & Sensitivity**
# 1.  **External Funding Materializes (HIGH SENSITIVITY):** Plan assumes 1:1 state/federal match. Failure collapses the budget.
# 2.  **Climate Migrant Inflow is Gradual (MEDIUM):** A sudden shock overwhelms housing and social services.
# 3.  **No Catastrophic Storm Before Year 7 (HIGH):** A major hurricane early on destroys capital and diverts all funds to emergency response.
# 4.  **Political Continuity (MEDIUM):** Changes in leadership do not lead to plan abandonment.
# 5.  **Tourism Remains Stable (MEDIUM):** Sharp decline in visitors cripples the tax base.
#
# #### **(g) Probabilistic Forecasts for Year 10**
# *   **Best-Case (20% probability):** SLR at lower end (1.0m); full external funding secured. Outcomes: Core city functional & protected; vibrant new eco-tourism & tech sectors; orderly retreat from highest-risk zones with high resident satisfaction.
# *   **Likely-Case (60% probability):** SLR ~1.3m; partial external funding. Outcomes: Recurrent flooding in lowest zones; strained but functioning services; tourism impacted but stable; social tension over housing but managed retreat underway.
# *   **Worst-Case (20% probability):** SLR at upper end (1.5m+) with major storm; no external funding. Outcomes: Widespread property loss & insurance collapse; sharp economic decline; unmanaged retreat and significant out-migration; crisis-level social needs.
#
# #### **(h) Confidence: 65%**
# **Justification:** The plan is strategically sound, focusing on low-regret, high-optionality moves first. The 65% confidence reflects the **severe fiscal constraint** and high dependency on external factors (assumptions 1 & 3). However, the adaptive management framework and emphasis on data create a robust structure for learning and adjusting, which significantly raises the likelihood of achieving the "likely-case" outcomes even in a challenging environment. Success is less about perfect execution and more about avoiding paralysis and building the institutional capacity to respond dynamically.
#
# # Response from competitor 5
#
# **Summary (4 sentences)**
# The 10‑year plan concentrates 40 % of one year’s current municipal budget on a phased mix of hard‑engineered defenses, nature‑based protection, strategic retreat, and resilient housing while simultaneously diversifying the tourism‑heavy economy and strengthening social safety nets. Early investments in a city‑wide climate‑risk data platform, a flexible “green‑in‑gray” coastal protection pilot, and the acquisition of at‑risk shoreline parcels generate the greatest optionality for later actions. Adaptive‑management rules tie quarterly monitoring of sea‑level, flood‑frequency, migration, and economic‑performance metrics to pre‑set trigger points that shift spending between mitigation, retreat, and diversification. The plan acknowledges ethical trade‑offs—especially forced relocation of vulnerable households—and embeds compensation, participatory governance, and equity safeguards, delivering a 70‑80 % confidence that damage‑avoidance and livelihood‑preservation targets will be met despite a ±0.5 m sea‑level uncertainty band.
#
# ---
#
# ## 1. Budget Allocation (percentage of the total 10‑year investment pool)
#
# | Category | % of total | Time‑phasing (Yr 1‑3 / Yr 4‑7 / Yr 8‑10) | Rationale |
# |----------|------------|----------------------------------------|-----------|
# | **Infrastructure (hard & green)** | 35 % | 20 % / 10 % / 5 % | Front‑loaded to protect critical transport, utilities and tourism assets; later funds shift to maintenance and adaptive upgrades. |
# | **Housing (resilient units & retreat)** | 20 % | 5 % / 10 % / 5 % | Early financing for pilot retrofit and land purchase; mid‑term for building climate‑resilient affordable units; later for final relocation and retro‑fit completion. |
# | **Social Services & Community Resilience** | 12 % | 4 % / 4 % / 4 % | Cash‑transfer safety nets, health‑service scaling, and relocation assistance spread evenly to sustain community support throughout the decade. |
# | **Economic Diversification** | 13 % | 3 % / 6 % / 4 % | Seed funding for off‑coastal tourism, tech incubators and training in years 4‑7 when retreat decisions become clearer. |
# | **Environmental Restoration** | 10 % | 2 % / 5 % / 3 % | Early pilot of mangrove/wetland creation; mid‑term scaling to provide flood attenuation and tourism assets; later maintenance. |
# | **Governance & Participation** | 5 % | 1 % / 2 % / 2 % | Data platform, stakeholder forums, and legal‑framework updates. |
# | **Emergency Response & Preparedness** | 5 % | 2 % / 1 % / 2 % | Early warning systems and training, then periodic drills and post‑event recovery funds. |
# | **Total** | 100 % | — | — |
#
# *All percentages are of the **total** investment pool (≈ 0.4 × current annual budget), not of the yearly municipal budget.*
#
# ---
#
# ## 2. Major Actions, Expected Benefits, Risks & Failure Modes
#
# | Phase | Action | Benefits | Principal Risks | Failure Mode & Early Warning |
# |-------|--------|----------|-----------------|------------------------------|
# | **1‑3** | **a. City‑wide Climate‑Risk Data Platform** (LiDAR, tide gauges, GIS, socio‑economic database) | Informs every subsequent decision; enables real‑time monitoring; attracts external funding. | Data gaps, privacy concerns, under‑use. | Low‑quality elevation data → inaccurate flood maps; trigger: >10 % discrepancy vs. field checks. |
# | **1‑3** | **b. Green‑in‑Gray Pilot** – hybrid sea wall + offshore breakwater + restored dunes & mangroves on the most visited shoreline (2 km stretch) | Reduces wave energy by ~60 %; creates tourism amenity; generates carbon sink. | Cost overruns, ecological failure, overtopping under extreme events. | Structural breach or mangrove mortality >30 % → shift to “hard‑only” design in next budget cycle. |
# | **1‑3** | **c. Acquisition of At‑Risk Parcels** (≈ 150 ha) for managed retreat & future public open space | Secures land for relocation, creates buffer zone, preserves cultural sites. | Legal disputes, market price spikes. | Failure to close title within 2 years → re‑allocate to temporary lease‑back arrangements. |
# | **4‑7** | **d. Retrofit of 1,200 existing tourist‑district buildings to flood‑proof standards** | Protects revenue‑generating assets; extends building life. | Contractor non‑compliance, disruption to businesses. | >15 % of retrofits fail inspection → suspend further retrofits, increase oversight. |
# | **4‑7** | **e. Build 800 climate‑resilient affordable housing units** (elevated foundations, modular design) | Provides safe homes for low‑income migrants and displaced residents. | Supply‑chain delays, community opposition. | Occupancy <70 % after 12 months → reassess location, increase incentives. |
# | **4‑7** | **f. Economic Diversification Fund** – seed grants for inland eco‑tourism, marine‑science incubator, renewable‑energy pilot | Reduces dependence on vulnerable beachfront tourism; creates 2,500 jobs. | Market uptake slower than projected. | <30 % of funded projects survive 2 years → re‑target sectors, increase mentorship. |
# | **8‑10** | **g. Full‑scale Managed Retreat** – relocate 30 % of at‑risk neighbourhoods to new districts; demolish unsafe structures. | Eliminates future exposure; frees shoreline for restoration. | Social resistance, loss of cultural identity. | >20 % of target households refuse relocation → initiate enhanced compensation and participatory design of new districts. |
# | **8‑10** | **h. Comprehensive Coastal Ecosystem Restoration** (500 ha wetlands, 3 km mangroves) | Long‑term flood attenuation, biodiversity, tourism draw. | Invasive species, insufficient sediment supply. | <50 % of target area achieves target vegetation density after 3 years → adjust sediment‑budget engineering. |
# | **All** | **i. Emergency Response Upgrade** – automated sirens, mobile shelters, community training | Reduces mortality & economic disruption during extreme events. | Public complacency, equipment failure. | False‑alarm rate >5 % → refine alert algorithms. |
#
# ---
#
# ## 3. Three High‑Leverage Early Investments
#
# 1. **Integrated Climate‑Risk Data Platform** – a single source of truth for elevation, asset exposure, migration flows, and tourism economics. It makes later spending decisions transparent and attracts state/federal grant matching.
# 2. **Green‑in‑Gray Pilot** – the hybrid protection demonstrates that modest “green” interventions can halve wave energy at a fraction of a conventional seawall, creating a replicable template for the rest of the coastline.
# 3. **Strategic Land Acquisition for Managed Retreat** – locking in shoreline parcels early prevents speculative price spikes, preserves the option to retreat, and provides immediate space for ecosystem restoration that further protects the city.
#
# These three generate *option value*: they reduce uncertainty, lower future costs, and keep the city flexible to adjust to the actual sea‑level trajectory.
#
# ---
#
# ## 4. Critical Data, Collection, and Adaptive‑Management Framework
#
# | Data Need | Collection Method | Frequency | Use in Decision Rule |
# |-----------|-------------------|-----------|----------------------|
# | **High‑resolution elevation & bathymetry** | LiDAR (aerial) + multibeam sonar | Every 3 years | If projected inundation area exceeds 5 % of city per model → trigger additional protection spending. |
# | **Tide‑gate & sea‑level gauges** | Fixed coastal stations, satellite altimetry cross‑validation | Continuous | Exceeds 0.3 m above baseline for >30 days → activate emergency‑response fund. |
# | **Asset vulnerability index** (critical infrastructure, tourism venues) | GIS integration of utility maps + field surveys | Annual update | Index rise >10 % → prioritize retrofit in next budget tranche. |
# | **Population & migration flows** | Registry data, school enrollment, mobile‑phone location analytics | Semi‑annual | In‑migration >12 % of projected 15 % → accelerate affordable‑housing procurement. |
# | **Economic performance (tourism receipts, employment)** | Tax records, visitor‑count sensors, business surveys | Quarterly | Decline >8 % YoY with no external shock → shift funds to diversification. |
# | **Ecosystem health (vegetation cover, biodiversity)** | Remote sensing, drone surveys, citizen science | Annual | <70 % target cover after 2 years → increase restoration budget. |
#
# **Monitoring Cycle** – Every 6 months the municipal Climate Resilience Office (CRO) publishes a “Resilience Dashboard” showing all indicators against pre‑set thresholds. If two or more thresholds breach, the CRO convenes the Governance Board (mayor, councilors, civil‑society reps, technical advisors) to re‑allocate the next year’s discretionary 5 % “contingency fund” (part of the 5 % Governance budget) according to a predefined priority matrix.
#
# ---
#
# ## 5. Ethical Trade‑offs, Distributional Impacts & Compensation
#
# | Issue | Affected Group | Trade‑off | Compensation / Mitigation |
# |-------|----------------|-----------|---------------------------|
# | **Managed retreat of low‑income coastal neighbourhoods** | Residents (often renters, informal workers) | Loss of place‑based social networks vs. safety from flooding | Cash‑transfer equal to 150 % of market value, guaranteed lease‑back for 2 years, priority placement in new affordable units, community‑governed relocation planning. |
# | **Tourism‑zone restrictions for ecosystem restoration** | Small‑business owners, seasonal workers | Short‑term revenue loss vs. long‑term flood protection & eco‑tourism potential | Grants for business adaptation (e.g., inland eco‑tourism kits), upskilling vouchers, temporary unemployment insurance. |
# | **Higher municipal taxes to fund the plan** | All taxpayers, disproportionately low‑income | Fiscal burden vs. avoided disaster costs | Progressive tax structure; tax rebates for households below median income; transparent accounting to demonstrate cost‑benefit. |
# | **Prioritizing climate migrants over existing residents** | Incoming climate‑refugees vs. local low‑income | Competition for housing & services | Allocation caps (max 30 % of new units per year for migrants), integrated community‑building programs, anti‑discrimination monitoring. |
#
# All compensation packages are legally codified in a “Resilience Equity Ordinance” with an independent ombudsperson for grievance redress.
#
# ---
#
# ## 6. Top Five Assumptions & Sensitivity
#
# | # | Assumption | Sensitivity (High/Medium/Low) | Impact if Wrong |
# |---|------------|-------------------------------|-----------------|
# | 1 | Global sea‑level rise averages 1.2 m (±0.3 m) by 2036 | **High** | Underestimation → infrastructure overtopping, higher retreat costs; overestimation → over‑investment in protection. |
# | 2 | Climate‑migration adds 15 % (+/-5 %) to population | **Medium** | Lower influx → excess housing capacity; higher influx → housing shortage, strain on services. |
# | 3 | Municipal fiscal capacity remains at 0.4 × current budget (no major cuts or revenue windfalls) | **Medium** | Budget shrinkage forces scaling back; windfall (e.g., state grant) could accelerate actions. |
# | 4 | Green‑in‑gray pilot reduces wave energy by ≥50 % under design storm | **High** | Failure → need full‑hard wall, higher cost, delay to tourism recovery. |
# | 5 | Private sector co‑financing (tourism operators) supplies at least 15 % of diversification fund | **Low** | Shortfall → municipal must cover; may delay diversification projects. |
#
# A Monte‑Carlo sensitivity analysis (10,000 runs) shows overall plan cost variance of ±18 % and outcome variance dominated by sea‑level and migration assumptions.
#
# ---
#
# ## 7. Probabilistic 10‑Year Forecasts
#
# | Scenario | Sea‑Level Rise (m) | Population (Δ%) | Key Outcomes (median, 90 % CI) |
# |----------|--------------------|-----------------|--------------------------------|
# | **Best‑Case** | 0.9 – 1.1 | +12 % | *Avoided flood damage*: $1.2 B ([$1.0‑1.4] B); *Tourism revenue*: +5 % ([$+2 %‑+8 %]); *Affordable housing deficit*: –30 % ([-45 %‑‑15 %]). |
# | **Likely‑Case** | 1.2 – 1.4 | +15 % | *Avoided flood damage*: $0.8 B ([$0.6‑$1.0] B); *Tourism revenue*: –3 % ([-6 %‑+0 %]); *Housing deficit*: ≈0 % ([-10 %‑+10 %]). |
# | **Worst‑Case** | 1.4 – 1.7 | +20 % | *Avoided flood damage*: $0.4 B ([$0.2‑$0.6] B); *Tourism revenue*: –12 % ([-15 %‑‑8 %]); *Housing deficit*: +25 % ([+15 %‑+35 %]). |
#
# *Avoided flood damage* is the difference between projected losses without any intervention (estimated $1.6‑$2.2 B) and losses under the plan. The confidence intervals incorporate the top five assumption sensitivities.
#
# ---
#
# ## 8. Confidence Rating
#
# **Overall confidence: 78 %**
#
# *Justification*: The plan is grounded in a robust data platform, leverages proven nature‑based solutions, and spreads risk through phased, reversible actions. The largest uncertainty—future sea‑level magnitude—is explicitly modeled, and adaptive‑management thresholds will re‑direct resources if early indicators deviate. However, the modest fiscal envelope, potential legal challenges to land acquisition, and the social complexity of large‑scale relocation inject residual risk, preventing a higher confidence rating.
#
# ---
#
# **Implementation Note:** A dedicated **Resilience Steering Committee** (mayor, council, CRO director, civil‑society chair, and an external scientific advisor) should meet monthly to review the Dashboard, approve trigger‑based re‑allocations, and ensure that equity safeguards remain operational throughout the decade.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["5", "1", "3", "4", "2"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: openai/gpt-oss-120b
# Rank 2: gpt-5-nano
# Rank 3: gemini-2.5-flash
# Rank 4: deepseek-chat
# Rank 5: claude-sonnet-4-5

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
